# %% [markdown]
# # <div style="padding:20px;color:white;margin:0;font-size:100%;font-family:Verdana;text-align:center;display:fill;border-radius:15px;background-color:green;letter-spacing:1px;overflow:hidden"><b> EDA PROJECTS-3</b></div>
# <p style="text-align: center;"><font color='dodgerblue'> <b>Human Resources & Kyphosis & Cancer & Daily Stock Project</b><font color='orange'><p>
#
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [LinkedIn](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# In this project, we will analyze human resources data by performing data wrangling & EDA.
#
# We will learn how to:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:100%;font-family:Verdana;text-align:center;display:fill;border-radius:15px;background-color:dodgerblue;letter-spacing:1px;overflow:hidden"><b> HUMAN RESOURCES DATASET</b></div>
#
# <p style="text-align: center"><font color='Magenta'> <b>DS-4</b><font color='black'><p>
#
# <p style="text-align: center;"><font color='dodgerblue'> <b>Data Analytics Final Project  | May 2024</b><font color='orange'><p>

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <h3 align="left"><font color=dodgerblue> 🎯 Project Description:</font></h3>
#
#
# *This project involves an in-depth Exploratory Data Analysis (EDA) of a Human Resources dataset. The primary objective is to gain insights into employee demographics, job roles, satisfaction levels, and other relevant attributes to understand patterns and trends that could inform better decision-making in human resource management. The analysis will involve data cleaning, imputation, visualization, and interpretation of key findings to derive actionable insights.*

# %% [markdown]
# <h3 align="left"><font color=dodgerblue> 📝 About the Dataset </font></h3>

# %% [markdown]
# **Meaning of Columns**
#
# |STT | Attribute Name | Meaning |
# |:---| :--- |:--- |
# | 1 | Age | Employee's age |
# | 2 | Gender | Employee's Gender |
# | 3 | BusinessTravel | Frequency of employees' business trips |
# | 4 | DailyRate | Daily salary rate for employees |
# | 5 | Department | Office of employees |
# | 6 | DistanceFromHome | Distance from home in miles to work |
# | 7 | Education | Level of education achieved by staff |
# | 8 | EducationField | Employee's field of study |
# | 9 | EmployeeCount | Total number of employees in the organization |
# | 10 | EmployeeNumber | A unique identifier for each employee record |
# | 11 | EnvironmentSatisfaction | Employee satisfaction with their working environment |
# | 12 | HourlyRate | Hourly rate for employees |
# | 13 | JobInvolvement | Level of involvement required for the employee's job |
# | 14 | JobLevel | Employee's level of work |
# | 15 | JobRole | The role of employees in the organization |
# | 16 | JobSatisfaction | Employee satisfaction with their work |
# | 17 | MaritalStatus | Employee's marital status |
# | 18 | MonthlyIncome | Employee's monthly income |
# | 19 | MonthlyRate | Monthly salary rate for employees |
# | 20 | NumCompaniesWorked | Number of companies the employee worked for |
# | 21 | Over18 | Whether the employee is over 18 years old |
# | 22 | OverTime | Do employees work overtime |
# | 23 | PercentSalaryHike | Salary increase rate for employees |
# | 24 | PerformanceRating | The performance rating of the employee |
# | 25 | RelationshipSatisfaction | Employee satisfaction with their relationships |
# | 26 | StandardHours | Standard working hours for employees |
# | 27 | StockOptionLevel | Employee stock option level |
# | 28 | TotalWorkingYears | Total number of years the employee has worked |
# | 29 | TrainingTimesLastYear | Number of times employees were taken to training in the last year |
# | 30 | WorkLifeBalance | Employees' perception of their work-life balance |
# | 31 | YearsAtCompany | Number of years employees have been with the company |
# | 32 | YearsInCurrentRole | Number of years the employee has been in their current role |
# | 33 | YearsSinceLastPromotion | Number of years since employee's last promotion |
# | 34 | YearsWithCurrManager | Number of years an employee has been with their current manager |
# | 35 | Attrition | Does the employee leave the organization |

# %% [markdown]
# **Meaning of Classifications**
#
# - Education:
# 1 'Below College'
# 2 'College'
# 3 'Bachelor'
# 4 'Master'
# 5 'Doctor'
#
# - EnvironmentSatisfaction:
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# - JobInvolvement
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# - JobSatisfaction:
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# - PerformanceRating:
# 1 'Low'
# 2 'Good'
# 3 'Excellent'
# 4 'Outstanding'
#
# - RelationshipSatisfaction:
# 1 'Low'
# 2 'Medium'
# 3 'High'
# 4 'Very High'
#
# - WorkLifeBalance:
# 1 'Bad'
# 2 'Good'
# 3 'Better'
# 4 'Best'

# %% [markdown]
# ## <font color=#2865c8> <b> UNDERSTANDING THE DATA </b><font color='orange'>

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %% [markdown]
# ### <font color='dodgerblue'> <b> Import The Libraries</b><font color='orange'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### <font color='dodgerblue'> <b> Perform Basic Statistical Data Analysis </b><font color='orange'>

# %%
df0 = pd.read_csv('Human_Resources.csv')
df = df0.copy()

# %%
df.shape

# %%
df.dtypes

# %%
df.head()

# %%
df.tail()

# %%
df.mean()

# %%
df.info()

# %%
df.describe().T

# %%
df.describe(include="object").T

# %%
df.duplicated().sum()

# %% [markdown]
#  📍 **PRACTICE OPPORTUNITY #1:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
df.Age.agg([np.mean, max, min])

# %%
df.Age.describe().T

# %% [markdown]
# ##  <font color=#2865c8> <b> DATA PREPERATION </b><font color='black'>
# Hint:
# - Dropping irrelevant columns and rows
# - Renaming Columns
# - Identifying missing values and dublicated columns
# - Feature Creation

# %% [markdown]
# ### <font color='dodgerblue'> <b>Change the column names if necessary</b><font color='black'>
# Hint:
#
# - `df.rename(columns=lambda x: x.split('(')[0], inplace=True)`  or
# - `df.rename(columns=str.lower, inplace=True)`
# - `df.columns.str.lower()`
# - `df.columns = ['X',	'Y',	'Z'.....]`

# %%
df.columns.str.lower()

# %%
df=df0.copy()

# %% [markdown]
# ##  <font color='dodgerblue'> <b> DEALING WITH MISSING DATA </b><font color='black'>

# %% [markdown]
# **Tasks:**
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %% [markdown]
# ### <font color='dodgerblue'> <b>Checking the Filling Missing Values </b><font color='orange'>

# %%
#Let's locate rows that have Null values
df.isnull().sum()

# %%
#Notice Row index 6 has many missing values
df.iloc[6:7]

# %%
df.columns[df.iloc[6].isnull()]

# %%
df.iloc[6].isnull().sum().sum()

# %%
#Let's see the total number of missing elements per column
df.isnull().sum() #All missing values

# %%
df.isnull().sum().sum() #Total number of missing values

# %%
df[df.isnull().any(axis=1)]

# %%
#Drop any row that contains a Null value
df.dropna(inplace=True)

# %%
#Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463
df.info()

# %%
#Notice that row 1 for example is no longer existing!
df.head()

# %%
#Let's check if we still have any missing values
df.isnull().sum().sum()

# %%
#Let's read the raw data again using Pandas as follows
df=df0.copy()
df.head()

# %% [markdown]
# ### <font color='dodgerblue'> <b>Exploring Alternative (smarter) Methods to Deal with Missing Values </b><font color='orange'>

# %% [markdown]
# Hint:
#
# Numerical values;
# - `df['column1'].fillna(df['column1'].mean())`
#
# Categorical values;
# - `df['department'].fillna(df['department'].mode()[0])`
# - `df['department'].fillna(method='ffill', inplace=True)`  or `bfill`
#
# Filling by condition & group;
# - `df.loc[df['salary'] >= 100, 'position'] =  df.loc[df['salary'] >= 100, 'position'].fillna(df.loc[df['salary'] >= 100, 'position'].mode()[0])`
# - `df['position'].fillna(df.groupby(['department'])['position'].transform(lambda x: x.mode()[0]), inplace=True)`
# - `df['salary'].fillna(df.groupby(['position','department'])['salary'].transform('mean'),inplace=True)`

# %%
df[df.isnull().any(axis=1)]  #see the missing values

# %%
df.isnull().sum() # see the missing values by columns

# %%
# Creating a heatmap for all columns and their correlations to predict the best options for filling the missing values

plt.figure(figsize=(15, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# 1) MonthlyIncome Review;

df[df['MonthlyIncome'].isnull()]

# %%
# MonthlyIncome is most highly related with three columns: JobLevel, TotalWorkingYears, and Age.

df[["MonthlyIncome", "JobLevel", "TotalWorkingYears", "Age"]].corr()

# %%
#Calculate the average monthly income

df.MonthlyIncome.mean()

# %%
# Calculate the Average of MonthlyIncome column by 'JobLevel','TotalWorkingYears'

df.groupby(['JobLevel','TotalWorkingYears'])['MonthlyIncome'].transform('mean')

# %%
# Filling the missing values of MonthlyInCome column by the Calculated Average of MonthlyIncome

df['MonthlyIncome'].fillna(df.groupby(['JobLevel','TotalWorkingYears'])['MonthlyIncome'].transform('mean'),inplace=True)

# %%
df[['MonthlyIncome','JobLevel','TotalWorkingYears']].head()   # checking the Null values on MonthlyIncome

# %%
# 2) Department Review;

df[df['Department'].isnull()]

# %%
# Department column is most highly related with the column 'JobRole'.

df.groupby('Department')['JobRole'].value_counts()

# %%
# Fill the missing values of the Department column by the mode() of 'JobRole' column

df['Department'].fillna(df.groupby(["JobRole"])["Department"].transform(lambda x: x.mode()[0]),inplace=True)

# %%
df['Department'].isnull().sum() # Checking the Department columns's Null values

# %%
df.iloc[[7]]

# %%
# 3) EducationField Review;

df[df['EducationField'].isnull()]

# %%
# EducationField column is most highly related with the columns; Department, TotalWorkingYears or JobRole.

df.groupby(["Department","MonthlyIncome"])["EducationField"].value_counts()

# %%
# Fill the missing values of EducationField column by the mode of "Department" and "TotalWorkingYears" column

df.EducationField.fillna(df.groupby(["Department","TotalWorkingYears"])["EducationField"].transform(lambda x: x.mode()[0]),inplace=True)

# %%
# 4) EmployeeNumber Review;

df[df['EmployeeNumber'].isnull()]

# %%
df['EmployeeNumber'].nunique()

# %%
df['EmployeeNumber'].agg([max , min])

# %%
df['EmployeeNumber'].agg([max , min])

# %%
# Fill the missing values of EmployeeNumber column

df['EmployeeNumber'].fillna(df['EmployeeNumber'].max()+1,inplace=True)

# %%
# 5) Gender Review;

df[df['Gender'].isnull()]

# %%
df.groupby(["Department","Gender","MaritalStatus"])["MonthlyIncome"].mean()

# %%
# Fill the missing values of Gender column

df['Gender'].fillna(df.groupby(["Department","MaritalStatus"])["Gender"].transform(lambda x: x.mode()[0]),inplace=True)

# %%
# 6) MaritalStatus Review;

df[df['MaritalStatus'].isnull()]

# %%
# Fill the missing values of MaritalStatus column

df['MaritalStatus'].fillna(df.groupby(["Department","Gender"])["MaritalStatus"].transform(lambda x: x.mode()[0]),inplace=True)

# %%
# 7) JobRole Review;

df[df['JobRole'].isnull()]

# %%
df.groupby(["Department","JobRole","EducationField","JobLevel"])["Gender"].value_counts(normalize=True)*100

# %%
# Fill the missing values of MaritalStatus column
df['JobRole'].fillna(df.groupby(["Department","EducationField","Gender","JobLevel"])["JobRole"].transform(lambda x: x.mode()[0]),inplace=True)

# %%
# 8) MonthlyRate Review

df[df['MonthlyRate'].isnull()]

# %%
# Fill the missing values of MonthlyRate column

#df.MonthlyRate.fillna(df.groupby(["Department","JobRole","EducationField","Gender"])["MonthlyRate"].transform(lambda x: x.mode()[0])

# %%
# 9) PercentSalaryHike Review;

df[df['PercentSalaryHike'].isnull()]

# %%
# Fill the missing values of PercentSalaryHike column

df.PercentSalaryHike.fillna(df.groupby(["Department","JobRole","Age"])["PercentSalaryHike"].transform(lambda x: x.mode()[0]),inplace=True)

# %%
#You can use Fillna to fill a given column with a certain value

# %% [markdown]
# 📍**PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
df[df.isnull().any(axis=1) ]

# %%
df[df['MonthlyRate'].isnull()]

# %%
# MonthlyRate Review
df.MonthlyRate.fillna(df.MonthlyRate.median(),inplace=True)

# %%
df[df.isnull().any(axis=1) ]

# %% [markdown]
# ##  <font color='dodgerblue'> <b> PERFORM ONE-HOT ENCODING [OPTIONAL] </b><font color='black'>

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df

# %%
hr_df['BusinessTravel'].unique()

# %%
hr_df['BusinessTravel']

# %%
BusinessTravel_Encoded = pd.get_dummies(hr_df['BusinessTravel'])
print(BusinessTravel_Encoded)

# %% [markdown]
# 📍**PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %%
#Import the Human Resources data and remove all missing values
df.dropna(inplace=True)

# %%
# How many unique categories exist in the Education Field column?
hr_df['EducationField'].nunique()

# %%
# Perform one hot encoding to the Education Field column
BusinessTravel_Encoded = pd.get_dummies(hr_df['EducationField'],drop_first=True)
print(BusinessTravel_Encoded)

# %% [markdown]
# ##  <font color='dodgerblue'> <b> PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL] </b><font color='black'>

# %% [markdown]
# Scaling, normalization, and standardization are common preprocessing steps to prepare data for machine learning models.
#
# - Normalization typically scales the values in a column to the range between 0 and 1.
# - Standardization transforms data to have zero mean and a standard deviation of 1.

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df

# %%
hr_df['Age'].values

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))

# %%
hr_df['Age'].head()

# %%
hr_df.describe()

# %% [markdown]
# 📍**PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %%
df['MonthlyIncome'].values

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['MonthlyIncome'] = scaler.fit_transform(df['MonthlyIncome'].values.reshape(-1,1))

# %%
df['MonthlyIncome'].head()

# %%
df.describe()

# %% [markdown]
# ## <font color='dodgerblue'> <b> PANDAS OPERATIONS/FILTERING </b><font color='black'>

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
# Pick certain rows that satisfy a certain criteria
hr_df [hr_df.Attrition == "Yes"]

# %%
# Pick certain rows that satisfy 2 or more critirea
hr_df [(hr_df.Attrition == "Yes") & (hr_df.Age < 30) & (hr_df.MonthlyIncome > 8000.0)]

# %%
# values that fall between a given range
hr_df [(hr_df.Age > 18) & (hr_df.Age < 21)]

# %%
hr_df[hr_df['Age'].between(25, 35)]

# %% [markdown]
# 📍**PRACTICE OPPORTUNITY #5:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
# High DailyRate individuals (1450+)
high_daily_rate_df = hr_df[hr_df['DailyRate'] >= 1450]
high_daily_rate_df.head()

# %%
#Daily Total Salery
total_daily_rate = high_daily_rate_df['DailyRate'].sum()

# %%
print("Daily Total Rate (1450+):", total_daily_rate)

# %% [markdown]
# ## <font color='dodgerblue'> <b> PERFORM BASIC EDA ON BOTH CLASSES </b><font color='black'>

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company!
# - Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
df = df0.copy()

# %%
#It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18'

columns_to_drop = ['EmployeeCount', 'StandardHours', 'Over18']
df = df.drop(columns=columns_to_drop)

# %%
df.head()

# %%
#Let's see how many employees left the company!
attrition_counts = df['Attrition'].value_counts()
attrition_counts

# %%
# View employees who left
df[df['Attrition'] == 'Yes']

# %% [markdown]
# 📍**PRACTICE OPPORTUNITY #6:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
# Filter the hr_df to only include the employees who stayed in the company
df_employees =df[df['Attrition'] == 'No']

# %%
df_left_employees =df[df['Attrition'] == 'Yes']

# %%
#Generate statistical summary for employees who stayed
df_employees.describe().T

# %%
#Generate statistical summary for employees who left
df_left_employees .describe().T

# %% [markdown]
# ## <font color='dodgerblue'> <b> PANDAS WITH FUNCTIONS </b><font color='black'>

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %%
#Let's assume the daily rate has increased by 10%
#Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)

def increase_by_10_percent(value):
    return value * 1.10

# %%
#assume that net worth increased by 10%
hr_df['UpdatedDailyRate'] = hr_df['DailyRate'].apply(increase_by_10_percent)

# %%
#You can apply a function to the DataFrame
hr_df.head()

# %% [markdown]
# 📍**PRACTICE OPPORTUNITY #7:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %%
# Define a function that doubles the DailyRate and adds $100 
def double_and_add(daily_rate):
    return daily_rate * 2 + 100

# %%
#Apply the function to the DataFrame
hr_df['UpdatedDailyRate2'] = hr_df['DailyRate'].apply(double_and_add)

# %%
#Calculate the updated total Daily Rate of all employees combined
total_updated_daily_rate = hr_df['UpdatedDailyRate2'].sum()

# %%
print("Updated Daily Rate2:", total_updated_daily_rate)

# %% [markdown]
# ##  <font color=#2865c8> <b> FEATURE RELATIONSHIPS </b><font color='black'>
# Hint:
# - Histogram, KDE
# - Scatterplot
# - Heatmap Correlation
# - Analysis of the graphs

# %%
#Correlation of MonthlyIncome and Age by 'Attrition' for both genders
plt.figure(figsize=(4,8))
sns.relplot(data=df, y="MonthlyIncome", x="Age", hue="Attrition",col='Gender')
plt.show()

# %%
# Correlation of 'Attrition' with all fileds
df_copy = df.copy()

#convert category attributes with only 2 distinct values to numeric by assigning labels
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df_copy['Attrition']=label_encoder.fit_transform(df['Attrition'])
df_copy['OverTime']=label_encoder.fit_transform(df['OverTime'])
df_copy['Gender']=label_encoder.fit_transform(df['Gender'])

# %%
#convert category attributes with more than 2 distinct values to numeric using one-hot vector
df_copy=pd.get_dummies(df_copy, columns=['BusinessTravel', 'Department', 'EducationField', 
                               'JobRole', 'MaritalStatus'])

# %%
plt.figure(figsize=(20,10))
correlations=df_copy.corr()
correlations['Attrition'].sort_values(ascending = False).plot(kind='bar');

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
# <h3 align="left"><font color=dodgerblue> ⚙️Analysis of the graphs</font></h3>
#
# - Attrition is the highest for both men and women from 18 to 35 years of age and gradually decreases.
# - As income increases, attrition decreases.
# - Attrition is much, much less in divorced women.
# - Attrition is higher for employees who usually travel than others, and this rate is higher for women than for men.
# - Attrition is the highest for those in level 1 jobs.
# - Women with the job position of manager, research director and technician laboratory have almost no attrition.
# - Men with the position of sales expert have a lot of attrition.

# %% [markdown]
# ## <font color='dodgerblue'> <b> HISTOGRAM AND CORRELATION </b><font color='black'>

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df

# %%
#Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['MonthlyIncome'], kde=True)
plt.title('MonthlyIncome Dağılımı')

plt.subplot(1, 2, 2)
sns.histplot(df['TotalWorkingYears'], kde=True)
plt.title('TotalWorkingYears Dağılımı')

plt.show()

# %%
#Job level is strongly correlated with total working hours
df[["JobLevel", "TotalWorkingYears"]].corr()
# Out:
#                    JobLevel  TotalWorkingYears
# JobLevel           1.000000           0.782208
# TotalWorkingYears  0.782208           1.000000

# %%
#Monthly income is strongly correlated with Job level
df[["MonthlyIncome", "JobLevel"]].corr()

# %%
#Monthly income is strongly correlated with total working hours
df[["MonthlyIncome", "TotalWorkingYears"]].corr()

# %%
#Age is strongly correlated with monthly income
df[["Age", "MonthlyIncome"]].corr()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Güçlü korelasyonları regression plot ile inceleme
plt.figure(figsize=(14, 10))

# İş Seviyesi ve Toplam Çalışma Yılları (Job Level vs Total Working Years)
plt.subplot(2, 2, 1)
sns.regplot(x='JobLevel', y='TotalWorkingYears', data=df)
plt.title('Job Level vs Total Working Years')

# Aylık Gelir ve İş Seviyesi (Monthly Income vs Job Level)
plt.subplot(2, 2, 2)
sns.regplot(x='JobLevel', y='MonthlyIncome', data=df)
plt.title('Monthly Income vs Job Level')

# Aylık Gelir ve Toplam Çalışma Yılları (Monthly Income vs Total Working Years)
plt.subplot(2, 2, 3)
sns.regplot(x='TotalWorkingYears', y='MonthlyIncome', data=df)
plt.title('Monthly Income vs Total Working Years')

# Yaş ve Aylık Gelir (Age vs Monthly Income)
plt.subplot(2, 2, 4)
sns.regplot(x='Age', y='MonthlyIncome', data=df)
plt.title('Age vs Monthly Income')

plt.tight_layout()
plt.show()

# %%
# Heatmap for the correlation between all fileds

plt.figure(figsize=(15, 10))
sns.heatmap(hr_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# 📍**PRACTICE OPPORTUNITY #8:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
#Change the color of the heatmap

plt.figure(figsize=(15, 10))
sns.heatmap(hr_df.corr(), annot=True, cmap='viridis', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:100%;font-family:Verdana;text-align:center;display:fill;border-radius:15px;background-color:dodgerblue;letter-spacing:1px;overflow:hidden"><b> KYPHOSIS DATASET</b></div>
#
# <p style="text-align: center"><font color='Magenta'> <b>DS-4</b><font color='black'><p>
#
# <p style="text-align: center;"><font color='dodgerblue'> <b>Data Analytics Final Project  | May 2024</b><font color='orange'><p>

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %% [markdown]
# # Cancer Project

# %% [markdown]
# ## PLOT SCATTERPLOT & COUNTPLOT USING SEABORN
# - **Seaborn is a visualization library that sits on top of matplotlib**
# - **Seaborn offers enhanced features compared to matplotlib**
# - **https://seaborn.pydata.org/examples/index.html*/*
# - **Check out the head of the dataframe**
# - **Check out the tail of the dataframe**
# - **Plot scatter plot between mean area and mean smoothness**
# - **Let's print out countplot to know how many samples belong to class #0 and #1**

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Plot the scatterplot between the mean radius and mean area. Comment on the plot**

# %% [markdown]
# ## PLOT PAIRPLOT, DISPLOT, AND HEATMAPS/CORRELATIONS USING SEABORN

# %% [markdown]
# - **Plot the pairplot**
# - **Strong correlation between the mean radius and mean perimeter, mean area and mean primeter**
# - **plot the distplot**
# - **Displot combines matplotlib histogram function with kdeplot() (Kernel density estimate)**
# - **KDE is used to plot the Probability Density of a continuous variable.**

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Plot two separate distplot for each target class #0 and target class #1**

# %% [markdown]
# # Daily Stock Project

# %% [markdown]
# - In this project, we will visualize stock prices using Seaborn and Matplotlib. 4 Stocks are considered including JP Morgan Chase (JP), Procter and Gamble (P&G) (PG), Apple (AAPL) and United Airlines (UAL).
# - Using the stock_daily_prices.csv and stocks_daily_returns.csv dataset included in the course/workshop package, please do the following:
#     - Import both datasets using Pandas.
#     - Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.
#     - Using Matplotlib, plot 4 stocks daily prices on multiple subplots.
#     - Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).
#     - Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.
#     - Using Seaborn, plot similar scatterplot between Apple and JP Morgan daily returns.
#     - Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.
#     - Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and Standard deviation for both stocks on top of the figure. What did you conclude from this graph?
#     - Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.
#     - Plot a 3D plot showing all daily returns from JPM, AAPL and UAL [External Research is required].

# %% [markdown]
# # <p style="background-color:green;font-family:verdana;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Human Resources & Kyphosis & Cancer & Daily Stock Project</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [LinkedIn](https://www.linkedin.com/company/techproeducation/mycompany/) |
