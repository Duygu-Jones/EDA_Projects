# %% [markdown]
# <div style="color:white;
#             display:fill;
#             border-radius:15px;
#             background-color:dodgerblue;
#             font-size:100%;
#             font-family:Verdana;
#             letter-spacing:1px">
#     <h1 style='padding: 20px;
#               color:white;
#               text-align:center;'>
#         Automated Data Visualization
#     </h1>
#     </div>
#
#
# <p style="text-align: right;"><font color='Magenta'> <b>Duygu Jones</b><font color='black'><p>
#
# <p style="text-align: right;"><font color='dodgerblue'> <b>Data_Science  | April_2024</b><font color='orange'><p>
#
# <b>Follow me </b>[Linkedin](https://www.linkedin.com/in/duygujones/) | [GitHub](https://github.com/Duygu-Jones) | [Kaggle](https://www.kaggle.com/duygujones) | [Tableau](https://public.tableau.com/app/profile/duygu.jones/vizzes) | [Source]()

# %%
# !pip install folium
# !pip install missingno
# !pip install skimpy
# !pip install wordcloud

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Suppress warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)


print("Environment setup completed.")
# Out:
# Environment setup completed.

# %%
df0 = pd.read_csv('googleplaystore.csv')
df = df0.copy()

# %% [markdown]
# ## <font color='darkred'> <b> Pandas Profiling  </b><font color='black'>

# %%
pip install ydata_profiling
# Out:
# Requirement already satisfied: ydata_profiling in c:\users\duygu jones\anaconda3\lib\site-packages (4.7.0)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (1.5.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from ydata_profiling) (3.7.4)
# Requirement already satisfied: pydantic>=2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (2.7.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (3.1.3)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (0.14.0)
# Requirement already satisfied: typeguard<5,>=4.1.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (4.1.5)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata_profiling) (0.59.0)
# Requirement already satisfied: PyWavelets in c:\users\duygu jones\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (1.5.0)
# Requirement already satisfied: pillow in c:\users\duygu jones\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata_profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata_profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata_profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata_profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\duygu jones\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata_profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2023.3.post1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from pydantic>=2->ydata_profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from pydantic>=2->ydata_profiling) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pydantic>=2->ydata_profiling) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2024.2.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (0.5.3)
# Requirement already satisfied: colorama in c:\users\duygu jones\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata_profiling) (0.4.6)
# Collecting pandas!=1.4.0,<3,>1.1 (from ydata_profiling)
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\duygu jones\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (3.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2023.3)
# Requirement already satisfied: six in c:\users\duygu jones\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata_profiling) (1.16.0)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# Successfully installed pandas-2.2.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Duygu Jones\anaconda3\Lib\site-packages\~-ndas'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autoviz 0.1.901 requires pandas<2.0, but you have pandas 2.2.2 which is incompatible.

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Profiling Report")
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ## <font color='darkred'> <b> SweetViz  </b><font color='black'>

# %%
pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\duygu jones\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\duygu jones\anaconda3\lib\site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from sweetviz) (3.7.4)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from sweetviz) (4.65.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from sweetviz) (1.11.4)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from sweetviz) (3.1.3)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from sweetviz) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: colorama in c:\users\duygu jones\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import sweetviz as sv
#
# File ~\anaconda3\Lib\site-packages\sweetviz\__init__.py:15
#      12 __license__ = "MIT"
#      14 # These are the main API functions
# ---> 15 from sweetviz.sv_public import analyze, compare, compare_intra
#      16 from sweetviz.feature_config import FeatureConfig
#      18 # This is the main report class; holds the report data
#      19 # and is used to output the final report
#
# File ~\anaconda3\Lib\site-packages\sweetviz\sv_public.py:4
#       1 from typing import Union, List, Tuple
#       2 import pandas as pd
# ----> 4 import sweetviz.dataframe_report
#       5 from sweetviz.feature_config import FeatureConfig
#       8 def analyze(source: Union[pd.DataFrame, Tuple[pd.DataFrame, str]],
#       9             target_feat: str = None,
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
#
# File ~\anaconda3\Lib\site-packages\sweetviz\dataframe_report.py:10
#       8 from sweetviz.sv_types import NumWithPercent, FeatureToProcess, FeatureType
#       9 import sweetviz.from_dython as associations
# ---> 10 import sweetviz.series_analyzer as sa
#      11 import sweetviz.utils as su
#      12 from sweetviz.graph_associations import GraphAssoc
#
# File ~\anaconda3\Lib\site-packages\sweetviz\series_analyzer.py:4
#       2 from sweetviz.sv_types import NumWithPercent, FeatureType, FeatureToProcess
#       3 from sweetviz.type_detection import determine_feature_type
# ----> 4 import sweetviz.series_analyzer_numeric
#       5 import sweetviz.series_analyzer_cat
#       6 import sweetviz.series_analyzer_text
#
# File ~\anaconda3\Lib\site-packages\sweetviz\series_analyzer_numeric.py:3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from sweetviz.graph_numeric import GraphNumeric
#       4 import sweetviz.sv_html as sv_html
#       5 from sweetviz.sv_types import NumWithPercent, FeatureType, FeatureToProcess
#
# File ~\anaconda3\Lib\site-packages\sweetviz\graph_numeric.py:8
#       5 import warnings
#       7 from sweetviz.config import config
# ----> 8 from sweetviz import sv_html_formatters
#       9 from sweetviz.sv_types import FeatureType, FeatureToProcess
#      10 import sweetviz.graph
#
# File ~\anaconda3\Lib\site-packages\sweetviz\sv_html_formatters.py:3
#       1 from decimal import Decimal
#       2 import numpy as np
# ----> 3 from sweetviz.graph_associations import CORRELATION_ERROR
#       4 from sweetviz.graph_associations import CORRELATION_IDENTICAL
#       7 def fmt_int_commas(value: float) -> str:
#
# File ~\anaconda3\Lib\site-packages\sweetviz\graph_associations.py:6
#       4 import matplotlib.pyplot as plt
#       5 from sweetviz.sv_types import FeatureType
# ----> 6 import sweetviz.graph
#       7 from sweetviz.config import config
#       8 import itertools
#
# File ~\anaconda3\Lib\site-packages\sweetviz\graph.py:14
#      11 from sweetviz import sv_html_formatters
#      12 from sweetviz.config import config
# ---> 14 register_matplotlib_converters()
#      15 #matplotlib.use('SVG')
#      16 #matplotlib.use('tkagg')
#      17 plt.rcParams['svg.fonttype'] = 'path'
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_misc.py:64, in register()
#      30 """
#      31 Helper function to convert DataFrame and Series to matplotlib.table.
#      32
#    (...)
#      59         ...                           cellLoc='center', colWidths=list([.2, .2]))
#      60 """
#      61 plot_backend = _get_plot_backend("matplotlib")
#      62 return plot_backend.table(
#      63     ax=ax, data=data, rowLabels=None, colLabels=None, **kwargs
# ---> 64 )
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1886, in _get_plot_backend(backend)
#    1883 key = "pandas_plotting_backends"
#    1884 # entry_points lost dict API ~ PY 3.10
#    1885 # https://github.com/python/importlib_metadata/issues/298
# -> 1886 if hasattr(eps, "select"):
#    1887     entry = eps.select(group=key)
#    1888 else:
#    1889     # Argument 2 to "get" of "dict" has incompatible type "Tuple[]";
#    1890     # expected "EntryPoints"  [arg-type]
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1817, in _load_backend(backend)
#    1750 def hexbin(
#    1751     self,
#    1752     x: Hashable,
#    (...)
#    1757     **kwargs,
#    1758 ) -> PlotAccessor:
#    1759     """
#    1760     Generate a hexagonal binning plot.
#    1761
#    1762     Generate a hexagonal binning plot of `x` versus `y`. If `C` is `None`
#    1763     (the default), this is a histogram of the number of occurrences
#    1764     of the observations at ``(x[i], y[i])``.
#    1765
#    1766     If `C` is specified, specifies values at given coordinates
#    1767     ``(x[i], y[i])``. These values are accumulated for each hexagonal
#    1768     bin and then reduced according to `reduce_C_function`,
#    1769     having as default the NumPy's mean function (:meth:`numpy.mean`).
#    1770     (If `C` is specified, it must also be a 1-D sequence
#    1771     of the same length as `x` and `y`, or a column label.)
#    1772
#    1773     Parameters
#    1774     ----------
#    1775     x : int or str
#    1776         The column label or position for x points.
#    1777     y : int or str
#    1778         The column label or position for y points.
#    1779     C : int or str, optional
#    1780         The column label or position for the value of `(x, y)` point.
#    1781     reduce_C_function : callable, default `np.mean`
#    1782         Function of one argument that reduces all the values in a bin to
#    1783         a single number (e.g. `np.mean`, `np.max`, `np.sum`, `np.std`).
#    1784     gridsize : int or tuple of (int, int), default 100
#    1785         The number of hexagons in the x-direction.
#    1786         The corresponding number of hexagons in the y-direction is
#    1787         chosen in a way that the hexagons are approximately regular.
#    1788         Alternatively, gridsize can be a tuple with two elements
#    1789         specifying the number of hexagons in the x-direction and the
#    1790         y-direction.
#    1791     **kwargs
#    1792         Additional keyword arguments are documented in
#    1793         :meth:`DataFrame.plot`.
#    1794
#    1795     Returns
#    1796     -------
#    1797     matplotlib.AxesSubplot
#    1798         The matplotlib ``Axes`` on which the hexbin is plotted.
#    1799
#    1800     See Also
#    1801     --------
#    1802     DataFrame.plot : Make plots of a DataFrame.
#    1803     matplotlib.pyplot.hexbin : Hexagonal binning plot using matplotlib,
#    1804         the matplotlib function that is used under the hood.
#    1805
#    1806     Examples
#    1807     --------
#    1808     The following examples are generated with random data from
#    1809     a normal distribution.
#    1810
#    1811     .. plot::
#    1812         :context: close-figs
#    1813
#    1814         >>> n = 10000
#    1815         >>> df = pd.DataFrame({'x': np.random.randn(n),
#    1816         ...                    'y': np.random.randn(n)})
# -> 1817         >>> ax = df.plot.hexbin(x='x', y='y', gridsize=20)
#    1818
#    1819     The next example uses `C` and `np.sum` as `reduce_C_function`.
#    1820     Note that `'observations'` values ranges from 1 to 5 but the result
#    1821     plot shows values up to more than 25. This is because of the
#    1822     `reduce_C_function`.
#    1823
#    1824     .. plot::
#    1825         :context: close-figs
#    1826
#    1827         >>> n = 500
#    1828         >>> df = pd.DataFrame({
#    1829         ...     'coord_x': np.random.uniform(-3, 3, size=n),
#    1830         ...     'coord_y': np.random.uniform(30, 50, size=n),
#    1831         ...     'observations': np.random.randint(1,5, size=n)
#    1832         ...     })
#    1833         >>> ax = df.plot.hexbin(x='coord_x',
#    1834         ...                     y='coord_y',
#    1835         ...                     C='observations',
#    1836         ...                     reduce_C_function=np.sum,
#    1837         ...                     gridsize=10,
#    1838         ...                     cmap="viridis")
#    1839     """
#    1840     if reduce_C_function is not None:
#    1841         kwargs["reduce_C_function"] = reduce_C_function
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
report = sv.analyze(df)

# %%
report.show_html()

# %% [markdown]
# ## <font color='darkred'> <b> AutoViz  </b><font color='black'>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
pip install --user autoviz
# Out:
# Collecting autoviz
#   Using cached autoviz-0.1.901-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: emoji in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (2.11.1)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (2023.10.0)
# Collecting holoviews<=1.14.9 (from autoviz)
#   Using cached holoviews-1.14.9-py2.py3-none-any.whl.metadata (17 kB)
# Collecting hvplot~=0.7.3 (from autoviz)
#   Using cached hvplot-0.7.3-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting matplotlib<=3.7.4 (from autoviz)
#   Using cached matplotlib-3.7.4-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: nltk in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (3.8.1)
# Requirement already satisfied: numpy<1.24 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (1.23.5)
# Collecting pandas-dq>=1.29 (from autoviz)
#   Using cached pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pandas<2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (1.5.3)
# Requirement already satisfied: panel~=0.14.4 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (0.14.4)
# Requirement already satisfied: param==1.13.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (1.13.0)
# Requirement already satisfied: pyamg in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (5.1.0)
# Requirement already satisfied: scikit-learn in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (1.2.2)
# Requirement already satisfied: seaborn>=0.12.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (0.12.2)
# Requirement already satisfied: statsmodels in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (0.14.0)
# Requirement already satisfied: textblob in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (0.18.0.post0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (4.9.0)
# Requirement already satisfied: wordcloud in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (1.9.3)
# Requirement already satisfied: xgboost<1.7,>=0.82 in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: xlrd in c:\users\duygu jones\anaconda3\lib\site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\duygu jones\anaconda3\lib\site-packages (from holoviews<=1.14.9->autoviz) (3.0.0)
# Requirement already satisfied: colorcet in c:\users\duygu jones\anaconda3\lib\site-packages (from holoviews<=1.14.9->autoviz) (3.0.1)
# Requirement already satisfied: packaging in c:\users\duygu jones\anaconda3\lib\site-packages (from holoviews<=1.14.9->autoviz) (23.1)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from hvplot~=0.7.3->autoviz) (2.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<=3.7.4->autoviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<=3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<=3.7.4->autoviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<=3.7.4->autoviz) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<=3.7.4->autoviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<=3.7.4->autoviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<=3.7.4->autoviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas<2.0->autoviz) (2023.3.post1)
# Requirement already satisfied: markdown in c:\users\duygu jones\anaconda3\lib\site-packages (from panel~=0.14.4->autoviz) (3.4.1)
# Requirement already satisfied: requests in c:\users\duygu jones\anaconda3\lib\site-packages (from panel~=0.14.4->autoviz) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from panel~=0.14.4->autoviz) (4.65.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\duygu jones\anaconda3\lib\site-packages (from panel~=0.14.4->autoviz) (0.5.0)
# Requirement already satisfied: bleach in c:\users\duygu jones\anaconda3\lib\site-packages (from panel~=0.14.4->autoviz) (4.1.0)
# Requirement already satisfied: setuptools>=42 in c:\users\duygu jones\anaconda3\lib\site-packages (from panel~=0.14.4->autoviz) (68.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from scikit-learn->autoviz) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from scikit-learn->autoviz) (2.2.0)
# Requirement already satisfied: click in c:\users\duygu jones\anaconda3\lib\site-packages (from nltk->autoviz) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\duygu jones\anaconda3\lib\site-packages (from nltk->autoviz) (2023.10.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from statsmodels->autoviz) (0.5.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\duygu jones\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot~=0.7.3->autoviz) (3.1.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\duygu jones\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot~=0.7.3->autoviz) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot~=0.7.3->autoviz) (6.3.3)
# Requirement already satisfied: six in c:\users\duygu jones\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: colorama in c:\users\duygu jones\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel~=0.14.4->autoviz) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\duygu jones\anaconda3\lib\site-packages (from bleach->panel~=0.14.4->autoviz) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests->panel~=0.14.4->autoviz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests->panel~=0.14.4->autoviz) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests->panel~=0.14.4->autoviz) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests->panel~=0.14.4->autoviz) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot~=0.7.3->autoviz) (2.1.3)
# Using cached autoviz-0.1.901-py3-none-any.whl (68 kB)
# Using cached holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
# Using cached hvplot-0.7.3-py2.py3-none-any.whl (3.1 MB)
# Using cached matplotlib-3.7.4-cp311-cp311-win_amd64.whl (7.5 MB)
# Using cached pandas_dq-1.29-py3-none-any.whl (29 kB)
# Installing collected packages: matplotlib, pandas-dq, holoviews, hvplot, autoviz
# Successfully installed autoviz-0.1.901 holoviews-1.14.9 hvplot-0.7.3 matplotlib-3.7.4 pandas-dq-1.29
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Duygu Jones\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Duygu Jones\anaconda3\Lib\site-packages)
#   WARNING: The script holoviews.exe is installed in 'C:\Users\Duygu Jones\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from autoviz import AutoViz_Class
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from autoviz import AutoViz_Class
#
# ModuleNotFoundError: No module named 'autoviz'

# %%
AV = AutoViz_Class()

dft = AV.AutoViz("googleplaystore.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 AV = AutoViz_Class()
#       3 dft = AV.AutoViz("googleplaystore.csv")
#
# NameError: name 'AutoViz_Class' is not defined

# %% [markdown]
# # <p style="background-color:dodgerblue;font-family:arial;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Thank you, with the hope that you find it useful.
# </b></p>
#
# <b>If you want to be the first to be informed about new projects, please do not forget to follow me on.. | </b>[Linkedin](https://www.linkedin.com/in/duygujones/) | [Kaggle](https://www.kaggle.com/duygujones) | [Tableau](https://public.tableau.com/app/profile/duygu.jones/vizzes) | [Source:]()
#
# [10 Automated EDA Tools That Will Save You Hours of Work](https://medium.com/@riteshgupta.ai/10-automated-eda-tools-that-will-save-you-hours-of-work-b3edf3740fc2) | [Automate the exploratory data analysis (EDA) to understand the data](https://builtin.com/data-science/EDA-python)
