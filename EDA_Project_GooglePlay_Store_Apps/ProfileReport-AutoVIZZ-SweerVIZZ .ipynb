# %%
# !pip install folium
# !pip install missingno
# !pip install skimpy
# !pip install wordcloud

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly
import plotly.graph_objects as go
import plotly.express as px

from skimpy import skim
from wordcloud import WordCloud
import missingno as msno

import folium
from folium import plugins

# Plot settings
plt.rcParams["figure.figsize"] = (6, 4)

# Suppress warnings
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Display settings for pandas DataFrame
# pd.options.mode.chained_assignment = None
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

print("Environment setup completed.")
# Out:
# Environment setup completed.

# %%
df0 = pd.read_csv('googleplaystore.csv')
df = df0.copy()

# %% [markdown]
# ## <font color='darkred'> <b> Pandas Profiling  </b><font color='black'>

# %%
pip install ydata_profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.7.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-04-26 10:02:22.680168&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## <font color='darkred'> <b> SweetViz  </b><font color='black'>

# %%
pip install sweetviz

# %%
import sweetviz as sv

# %%
report = sv.analyze(df)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## <font color='darkred'> <b> AutoViz  </b><font color='black'>

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
pip install --user autoviz
# Out:
# ...
#   Using cached autoviz-0.1.901-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached holoviews-1.14.9-py2.py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached hvplot-0.7.3-py2.py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached matplotlib-3.7.4-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached pandas_dq-1.29-py3-none-any.whl.metadata (19 kB)
# ...
# Using cached autoviz-0.1.901-py3-none-any.whl (68 kB)
# Using cached holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
# Using cached hvplot-0.7.3-py2.py3-none-any.whl (3.1 MB)
# Using cached matplotlib-3.7.4-cp311-cp311-win_amd64.whl (7.5 MB)
# Using cached pandas_dq-1.29-py3-none-any.whl (29 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Duygu Jones\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Duygu Jones\anaconda3\Lib\site-packages)
# ...

# %%
from autoviz import AutoViz_Class
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from autoviz import AutoViz_Class
#
# ModuleNotFoundError: No module named 'autoviz'

# %%
AV = AutoViz_Class()

dft = AV.AutoViz("googleplaystore.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 AV = AutoViz_Class()
#       3 dft = AV.AutoViz("googleplaystore.csv")
#
# NameError: name 'AutoViz_Class' is not defined
