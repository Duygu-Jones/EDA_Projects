# %% [markdown]
# # <p style="background-color:dodgerblue;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Exploritary Data Analysis (EDA)</b></p>
#
# <p style="text-align: right;"><font color='Magenta'> <b>Duygu Jones</b><font color='black'><p>
# <p style="text-align: right;"><font color='dodgerblue'> <b>Data_Science  | April_2024</b><font color='orange'><p>
#
# <b>please do not forget to follow </b>[Linkedin](https://www.linkedin.com/in/duygujones/) | [GitHub](https://github.com/Duygu-Jones) | [Kaggle](https://www.kaggle.com/duygujones) | [Tableau](https://public.tableau.com/app/profile/duygu.jones/vizzes) | [Source]()>

# %% [markdown]
# ## <font color='Navy'> <b>Introduction to EDA</b><font color='black'>
# What are you going to do? what is your purpose?
#
# Explanation:

# %% [markdown]
# ## <font color='Navy'> <b>About the Dataset</b><font color='black'>
# Explain the dataset:
#
#     This data contains information about over 1000 roller coasters. Information was scraped from wikipedia.

# %% [markdown]
# ## <font color='Navy'> <b>Step 0: Import Libs and Reading Data files</b><font color='black'>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pylab as plt

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %% [markdown]
# - `plt.style.use('ggplot')`: This code sets the "ggplot" style for the plots in the matplotlib library. Matplotlib has various plot styles, and the "ggplot" style mimics the plotting style of the ggplot2 library in the R programming language. This style provides a more modern and sleek look for visualizing data.
#
# - `pd.set_option('display.max_columns', 200)`: This code sets the maximum number of columns to be displayed when printing DataFrame objects in the pandas library. Here, the `max_columns` option is set to 200. This ensures that a maximum of 200 columns will be displayed on the screen. This can be useful, especially when working with large DataFrame objects, to ensure that all columns are visible.

# %%
df=pd.read_csv('coaster_db.csv')
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  50 ft (15 m)
# 1            Lina Beecher                NaN          NaN           NaN
# 2                     NaN                NaN          NaN           NaN
# 3          Edwin Prescott                NaN          NaN           NaN
# 4          Edwin Prescott                NaN          NaN           NaN
#
#    Inversions Lift/launch system Cost  \
# 0         NaN            gravity  NaN
# 1         1.0                NaN  NaN
# 2         NaN                NaN  NaN
# 3         1.0                NaN  NaN
# 4         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
# 2                                                NaN
# 3  a single car. Riders are arranged 2 across in ...
# 4                                                NaN
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# 1                        NaN      NaN                   NaN      12
# 2                        NaN      NaN                   NaN     NaN
# 3                        NaN      NaN                   NaN     NaN
# 4                        NaN      NaN                   NaN     NaN
#
#                  Designer Max vertical angle          Drop Soft opening date  \
# 0  LaMarcus Adna Thompson                30°  43 ft (13 m)               NaN
# 1            Lina Beecher                NaN           NaN               NaN
# 2                     NaN                NaN           NaN               NaN
# 3         Edward A. Green                NaN           NaN               NaN
# 4         Edward A. Green                NaN           NaN               NaN
#
#   Fast Lane available            Replaced            Track layout  \
# 0                 NaN                 NaN  Gravity pulled coaster
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN  Switchback Railway                     NaN
# 4                 NaN                 NaN                     NaN
#
#   Fastrack available Soft opening date.1 Closing date Opened  Replaced by  \
# 0                NaN                 NaN          NaN    NaN          NaN
# 1                NaN                 NaN         1902    NaN          NaN
# 2                NaN                 NaN          NaN   1895          NaN
# 3                NaN                 NaN         1910    NaN  Giant Racer
# 4                NaN                 NaN         1912    NaN          NaN
#
#   Website Flash Pass Available Must transfer from wheelchair Theme  \
# 0     NaN                  NaN                           NaN   NaN
# 1     NaN                  NaN                           NaN   NaN
# 2     NaN                  NaN                           NaN   NaN
# 3     NaN                  NaN                           NaN   NaN
# 4     NaN                  NaN                           NaN   NaN
#
#   Single rider line available Restraint Style Flash Pass available  \
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
#
#   Acceleration Restraints Name  year_introduced  latitude  longitude  \
# 0          NaN        NaN  NaN             1884   40.5740   -73.9780
# 1          NaN        NaN  NaN             1895   40.5780   -73.9790
# 2          NaN        NaN  NaN             1896   41.5800   -81.5700
# 3          NaN        NaN  NaN             1901   40.5745   -73.9780
# 4          NaN        NaN  NaN             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed1    speed2  speed1_value speed1_unit  \
# 0      Wood         1884-06-16  6 mph   9.7 km/h           6.0         mph
# 1      Wood         1895-01-01     NaN       NaN           NaN         NaN
# 2     Other                NaN     NaN       NaN           NaN         NaN
# 3     Steel         1901-01-01     NaN       NaN           NaN         NaN
# 4     Steel         1901-01-01     NaN       NaN           NaN         NaN
#
#    speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 0        6.0          50.0          ft        NaN                 0
# 1        NaN           NaN         NaN        NaN                 1
# 2        NaN           NaN         NaN        NaN                 0
# 3        NaN           NaN         NaN        NaN                 1
# 4        NaN           NaN         NaN        NaN                 1
#
#    Gforce_clean
# 0           2.9
# 1          12.0
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## <font color='Navy'> <b>Step 1: Data Understanding</b><font color='black'>
#
# - Dataframe shape
# - head and tail
# - dtypes
# - describe-....

# %% [markdown]
# ### <font color='blue'> <b>Get the first 5 lines and /last/sample</b><font color='black'>

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  50 ft (15 m)
# 1            Lina Beecher                NaN          NaN           NaN
# 2                     NaN                NaN          NaN           NaN
# 3          Edwin Prescott                NaN          NaN           NaN
# 4          Edwin Prescott                NaN          NaN           NaN
#
#    Inversions Lift/launch system Cost  \
# 0         NaN            gravity  NaN
# 1         1.0                NaN  NaN
# 2         NaN                NaN  NaN
# 3         1.0                NaN  NaN
# 4         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
# 2                                                NaN
# 3  a single car. Riders are arranged 2 across in ...
# 4                                                NaN
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# 1                        NaN      NaN                   NaN      12
# 2                        NaN      NaN                   NaN     NaN
# 3                        NaN      NaN                   NaN     NaN
# 4                        NaN      NaN                   NaN     NaN
#
#                  Designer Max vertical angle          Drop Soft opening date  \
# 0  LaMarcus Adna Thompson                30°  43 ft (13 m)               NaN
# 1            Lina Beecher                NaN           NaN               NaN
# 2                     NaN                NaN           NaN               NaN
# 3         Edward A. Green                NaN           NaN               NaN
# 4         Edward A. Green                NaN           NaN               NaN
#
#   Fast Lane available            Replaced            Track layout  \
# 0                 NaN                 NaN  Gravity pulled coaster
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN  Switchback Railway                     NaN
# 4                 NaN                 NaN                     NaN
#
#   Fastrack available Soft opening date.1 Closing date Opened  Replaced by  \
# 0                NaN                 NaN          NaN    NaN          NaN
# 1                NaN                 NaN         1902    NaN          NaN
# 2                NaN                 NaN          NaN   1895          NaN
# 3                NaN                 NaN         1910    NaN  Giant Racer
# 4                NaN                 NaN         1912    NaN          NaN
#
#   Website Flash Pass Available Must transfer from wheelchair Theme  \
# 0     NaN                  NaN                           NaN   NaN
# 1     NaN                  NaN                           NaN   NaN
# 2     NaN                  NaN                           NaN   NaN
# 3     NaN                  NaN                           NaN   NaN
# 4     NaN                  NaN                           NaN   NaN
#
#   Single rider line available Restraint Style Flash Pass available  \
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
#
#   Acceleration Restraints Name  year_introduced  latitude  longitude  \
# 0          NaN        NaN  NaN             1884   40.5740   -73.9780
# 1          NaN        NaN  NaN             1895   40.5780   -73.9790
# 2          NaN        NaN  NaN             1896   41.5800   -81.5700
# 3          NaN        NaN  NaN             1901   40.5745   -73.9780
# 4          NaN        NaN  NaN             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed1    speed2  speed1_value speed1_unit  \
# 0      Wood         1884-06-16  6 mph   9.7 km/h           6.0         mph
# 1      Wood         1895-01-01     NaN       NaN           NaN         NaN
# 2     Other                NaN     NaN       NaN           NaN         NaN
# 3     Steel         1901-01-01     NaN       NaN           NaN         NaN
# 4     Steel         1901-01-01     NaN       NaN           NaN         NaN
#
#    speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 0        6.0          50.0          ft        NaN                 0
# 1        NaN           NaN         NaN        NaN                 1
# 2        NaN           NaN         NaN        NaN                 0
# 3        NaN           NaN         NaN        NaN                 1
# 4        NaN           NaN         NaN        NaN                 1
#
#    Gforce_clean
# 0           2.9
# 1          12.0
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# 1083           2022                      Steel – Launched
# 1084  June 16, 2016                      Steel – Launched
# 1085            NaN  Steel – 4th Dimension – Wing Coaster
# 1086           2022                   Steel – Single-rail
#
#                      Manufacturer Height restriction  \
# 1082            Anton Schwarzkopf     55 in (140 cm)
# 1083                      Intamin                NaN
# 1084                       Vekoma   4[2] ft (122 cm)
# 1085    S&S – Sansei Technologies                NaN
# 1086  Rocky Mountain Construction                NaN
#
#                          Model            Height  Inversions  \
# 1082                       NaN     111 ft (34 m)         3.0
# 1083             Blitz Coaster     178 ft (54 m)         2.0
# 1084  Motorbike roller coaster  78.1 ft (23.8 m)         0.0
# 1085              4D Free Spin     112 ft (34 m)         0.0
# 1086           Raptor – Custom     131 ft (40 m)         3.0
#
#             Lift/launch system Cost  \
# 1082   Booster Wheel Lift Hill  NaN
# 1083                       LSM  NaN
# 1084                LIM Launch  NaN
# 1085  Vertical chain lift hill  NaN
# 1086           Chain lift hill  NaN
#
#                                                  Trains       Park section  \
# 1082  3 trains with 5 cars. Riders are arranged 2 ac...                NaN
# 1083  2 trains with 5 cars. Riders are arranged 2 ac...                NaN
# 1084  7 trains with 7 cars. Riders are arranged 2 ac...                NaN
# 1085  Single car trains with riders arranged 4 acros...  Jungle X-Pedition
# 1086                                                NaN        DC Universe
#
#      Duration               Capacity G-force                  Designer  \
# 1082      NaN  1,500 riders per hour     4.7            Werner Stengel
# 1083      NaN                    NaN     NaN                       NaN
# 1084    ~2:00  1,680 riders per hour       4  Walt Disney Imagineering
# 1085     0:55                    NaN     NaN                       NaN
# 1086      NaN                    NaN     NaN                       NaN
#
#      Max vertical angle           Drop Soft opening date Fast Lane available  \
# 1082                NaN            NaN               NaN                 NaN
# 1083                95°            NaN               NaN                 NaN
# 1084                NaN            NaN               NaN                 NaN
# 1085                NaN            NaN               NaN                 NaN
# 1086                87°  127 ft (39 m)               NaN                 NaN
#
#                                     Replaced Track layout Fastrack available  \
# 1082                                     NaN          NaN                NaN
# 1083                                     NaN          NaN                NaN
# 1084                                     NaN          NaN                NaN
# 1085                               The Crypt          NaN                NaN
# 1086  Green Lantern: First Flight Tidal Wave          NaN                NaN
#
#      Soft opening date.1 Closing date Opened Replaced by           Website  \
# 1082                 NaN          NaN    NaN         NaN               NaN
# 1083                 NaN          NaN    NaN         NaN               NaN
# 1084                 NaN          NaN    NaN         NaN               NaN
# 1085                 NaN          NaN    NaN         NaN  Official website
# 1086                 NaN          NaN    NaN         NaN               NaN
#
#      Flash Pass Available  Must transfer from wheelchair Theme  \
# 1082                  NaN                            NaN   NaN
# 1083                  NaN                            NaN   NaN
# 1084                  NaN  Must transfer from wheelchair  Tron
# 1085                  NaN                            NaN   NaN
# 1086                  NaN                            NaN   NaN
#
#       Single rider line available Restraint Style Flash Pass available  \
# 1082                          NaN             NaN                  NaN
# 1083                          NaN             NaN                  NaN
# 1084  Single rider line available             NaN                  NaN
# 1085                          NaN             NaN                  NaN
# 1086                          NaN             NaN                  NaN
#
#      Acceleration Restraints                   Name  year_introduced  \
# 1082          NaN        NaN                    NaN             2022
# 1083          NaN        NaN                    NaN             2022
# 1084          NaN        NaN  TRON Lightcycle / Run             2022
# 1085          NaN        NaN                    NaN             2022
# 1086          NaN        NaN                    NaN             2022
#
#       latitude  longitude Type_Main opening_date_clean     speed1     speed2  \
# 1082       NaN        NaN     Steel                NaN    53 mph     85 km/h
# 1083   37.2339   -76.6426     Steel         2022-01-01    73 mph    117 km/h
# 1084       NaN        NaN     Steel         2016-06-16  59.3 mph   95.4 km/h
# 1085       NaN        NaN     Steel                NaN    34 mph     55 km/h
# 1086       NaN        NaN     Steel         2022-01-01    58 mph     93 km/h
#
#       speed1_value speed1_unit  speed_mph  height_value height_unit  \
# 1082          53.0         mph       53.0         111.0          ft
# 1083          73.0         mph       73.0         178.0          ft
# 1084          59.3         mph       59.3          78.1          ft
# 1085          34.0         mph       34.0         112.0          ft
# 1086          58.0         mph       58.0         131.0          ft
#
#       height_ft  Inversions_clean  Gforce_clean
# 1082        NaN                 3           4.7
# 1083        NaN                 2           NaN
# 1084        NaN                 0           4.0
# 1085        NaN                 0           NaN
# 1086        NaN                 3           NaN

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %% [markdown]
# ### <font color='blue'> <b>Check the dtype</b><font color='black'>

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# Fast Lane available               object
# Replaced                          object
# Track layout                      object
# Fastrack available                object
# Soft opening date.1               object
# Closing date                      object
# Opened                            object
# Replaced by                       object
# Website                           object
# Flash Pass Available              object
# Must transfer from wheelchair     object
# Theme                             object
# Single rider line available       object
# Restraint Style                   object
# Flash Pass available              object
# Acceleration                      object
# Restraints                        object
# Name                              object
# year_introduced                    int64
# latitude                         float64
# longitude                        float64
# Type_Main                         object
# opening_date_clean                object
# speed1                            object
# speed2                            object
# speed1_value                     float64
# speed1_unit                       object
# speed_mph                        float64
# height_value                     float64
# height_unit                       object
# height_ft                        float64
# Inversions_clean                   int64
# Gforce_clean                     float64
# dtype: object

# %% [markdown]
# ### <font color='blue'> <b>Look at the shape</b><font color='black'>

# %%
df.shape
# Out:
# (1087, 56)

# %% [markdown]
# ### <font color='blue'> <b>Look at the general information</b><font color='black'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
#  12  Lift/launch system             795 non-null    object
#  13  Cost                           382 non-null    object
#  14  Trains                         718 non-null    object
#  15  Park section                   487 non-null    object
#  16  Duration                       765 non-null    object
#  17  Capacity                       575 non-null    object
#  18  G-force                        362 non-null    object
#  19  Designer                       578 non-null    object
#  20  Max vertical angle             357 non-null    object
#  21  Drop                           494 non-null    object
#  22  Soft opening date              96 non-null     object
#  23  Fast Lane available            69 non-null     object
#  24  Replaced                       173 non-null    object
#  25  Track layout                   335 non-null    object
#  26  Fastrack available             19 non-null     object
#  27  Soft opening date.1            96 non-null     object
#  28  Closing date                   236 non-null    object
#  29  Opened                         27 non-null     object
#  30  Replaced by                    88 non-null     object
#  31  Website                        87 non-null     object
#  32  Flash Pass Available           50 non-null     object
#  33  Must transfer from wheelchair  106 non-null    object
#  34  Theme                          44 non-null     object
#  35  Single rider line available    81 non-null     object
#  36  Restraint Style                22 non-null     object
#  37  Flash Pass available           46 non-null     object
#  38  Acceleration                   60 non-null     object
#  39  Restraints                     24 non-null     object
#  40  Name                           35 non-null     object
#  41  year_introduced                1087 non-null   int64
#  42  latitude                       812 non-null    float64
#  43  longitude                      812 non-null    float64
#  44  Type_Main                      1087 non-null   object
#  45  opening_date_clean             837 non-null    object
#  46  speed1                         937 non-null    object
#  47  speed2                         935 non-null    object
#  48  speed1_value                   937 non-null    float64
#  49  speed1_unit                    937 non-null    object
#  50  speed_mph                      937 non-null    float64
#  51  height_value                   965 non-null    float64
#  52  height_unit                    965 non-null    object
#  53  height_ft                      171 non-null    float64
#  54  Inversions_clean               1087 non-null   int64
#  55  Gforce_clean                   362 non-null    float64
# dtypes: float64(8), int64(2), object(46)
# memory usage: 475.7+ KB

# %% [markdown]
# ### <font color='blue'> <b>Check for missing values</b><font color='black'>

# %%
df.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# Track layout                      752
# Fastrack available               1068
# Soft opening date.1               991
# Closing date                      851
# Opened                           1060
# Replaced by                       999
# Website                          1000
# Flash Pass Available             1037
# Must transfer from wheelchair     981
# Theme                            1043
# Single rider line available      1006
# Restraint Style                  1065
# Flash Pass available             1041
# Acceleration                     1027
# Restraints                       1063
# Name                             1052
# year_introduced                     0
# latitude                          275
# longitude                         275
# Type_Main                           0
# opening_date_clean                250
# speed1                            150
# speed2                            152
# speed1_value                      150
# speed1_unit                       150
# speed_mph                         150
# height_value                      122
# height_unit                       122
# height_ft                         916
# Inversions_clean                    0
# Gforce_clean                      725
# dtype: int64

# %% [markdown]
# ### <font color='blue'> <b>Check for duplicates</b><font color='black'>
# Hint:
#
# - `[df.duplicated()]`
# - `df.loc[df.duplicated()]`
#
# duplicate a 'column1' values in rows and create a new df1
# - `df.loc[df.duplicated(subset=['column1'])].head()`
# - `df = df.loc[~df.duplicated(subset=['column1', 'column2', 'column3'])].reset_index(drop=True).copy()`
#
# checking an example duplicate
# - `df.query('column1 == "Value1 in the column1"')`
#
# ---

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [coaster_name, Length, Speed, Location, Status, Opening date, Type, Manufacturer, Height restriction, Model, Height, Inversions, Lift/launch system, Cost, Trains, Park section, Duration, Capacity, G-force, Designer, Max vertical angle, Drop, Soft opening date, Fast Lane available, Replaced, Track layout, Fastrack available, Soft opening date.1, Closing date, Opened, Replaced by, Website, Flash Pass Available, Must transfer from wheelchair, Theme, Single rider line available, Restraint Style, Flash Pass available, Acceleration, Restraints, Name, year_introduced, latitude, longitude, Type_Main, opening_date_clean, speed1, speed2, speed1_value, speed1_unit, speed_mph, height_value, height_unit, height_ft, Inversions_clean, Gforce_clean]
# Index: []

# %%
df[df.duplicated(subset=['coaster_name'], keep=False)]
# Out:
#                             coaster_name                Length  \
# 14                           Derby Racer                   NaN
# 16                         Zippin Pippin      2,865 ft (873 m)
# 39                 Crystal Beach Cyclone      2,953 ft (900 m)
# 43                 Crystal Beach Cyclone      2,953 ft (900 m)
# 59           Blue Streak (Conneaut Lake)      2,900 ft (880 m)
# ...                                  ...                   ...
# 1063                  Lil' Devil Coaster     262.5 ft (80.0 m)
# 1064  Little Dipper (Conneaut Lake Park)                   NaN
# 1080                          Iron Gwazi    4,075 ft (1,242 m)
# 1082             American Dreier Looping    3,444 ft (1,050 m)
# 1084           Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
#
#                         Speed                   Location              Status  \
# 14                        NaN               Revere Beach             Removed
# 16           40 mph (64 km/h)                      Other                 NaN
# 39           60 mph (97 km/h)         Crystal Beach Park             Removed
# 43           60 mph (97 km/h)         Crystal Beach Park             Removed
# 59           50 mph (80 km/h)         Conneaut Lake Park              Closed
# ...                       ...                        ...                 ...
# 1063                      NaN  Six Flags Great Adventure           Operating
# 1064                      NaN         Conneaut Lake Park           Operating
# 1080        76 mph (122 km/h)    Busch Gardens Tampa Bay  Under construction
# 1082         53 mph (85 km/h)                      Other                 NaN
# 1084  59.3[1] mph (95.4 km/h)                      Other                 NaN
#
#                                            Opening date              Type  \
# 14                                                 1911     Wood – Racing
# 16                                                  NaN              Wood
# 39                                                 1926              Wood
# 43                                                 1926              Wood
# 59                                         May 23, 1938              Wood
# ...                                                 ...               ...
# 1063  1999 as Road Runner Railway; 2021 as Lil' Devi...    Steel – Kiddie
# 1064                                              1950s             Steel
# 1080                                                NaN    Steel – Wooden
# 1082                                                NaN             Steel
# 1084                                      June 16, 2016  Steel – Launched
#
#                      Manufacturer Height restriction  \
# 14                 Fred W. Pearce                NaN
# 16              The Gravity Group     48 in (122 cm)
# 39             Traver Engineering                NaN
# 43             Traver Engineering                NaN
# 59                            NaN                NaN
# ...                           ...                ...
# 1063                     Zamperla                NaN
# 1064      Allan Herschell Company                NaN
# 1080  Rocky Mountain Construction  48[1] in (122 cm)
# 1082            Anton Schwarzkopf     55 in (140 cm)
# 1084                       Vekoma   4[2] ft (122 cm)
#
#                              Model            Height  Inversions  \
# 14                             NaN               NaN         0.0
# 16                  Wooden Coaster      70 ft (21 m)         NaN
# 39                             NaN      96 ft (29 m)         NaN
# 43                             NaN      96 ft (29 m)         NaN
# 59     Out and Back roller coaster      77 ft (23 m)         0.0
# ...                            ...               ...         ...
# 1063  Family Gravity Coaster 80STD     13 ft (4.0 m)         0.0
# 1064                 Little Dipper               NaN         NaN
# 1080                   I-Box Track     206 ft (63 m)         2.0
# 1082                           NaN     111 ft (34 m)         3.0
# 1084      Motorbike roller coaster  78.1 ft (23.8 m)         0.0
#
#            Lift/launch system          Cost  \
# 14                        NaN      $140,000
# 16            Chain lift hill           NaN
# 39                 Chain-lift  $176,000 CDN
# 43                 Chain-lift  $176,000 CDN
# 59                        NaN           NaN
# ...                       ...           ...
# 1063          Chain lift hill           NaN
# 1064          Chain lift hill           NaN
# 1080          Chain lift hill           NaN
# 1082  Booster Wheel Lift Hill           NaN
# 1084               LIM Launch           NaN
#
#                                                  Trains          Park section  \
# 14                                                  NaN                   NaN
# 16                                                  NaN                   NaN
# 39                                                  NaN           Cyclone Bay
# 43                                                  NaN           Cyclone Bay
# 59    Single train with 3 cars. Riders are arranged ...                   NaN
# ...                                                 ...                   ...
# 1063  Single train with 6 cars. Riders are arranged ...  Looney Tunes Seaport
# 1064                                                NaN                   NaN
# 1080  2 trains with 6 cars. Riders are arranged 2 ac...               Morocco
# 1082  3 trains with 5 cars. Riders are arranged 2 ac...                   NaN
# 1084  7 trains with 7 cars. Riders are arranged 2 ac...                   NaN
#
#      Duration               Capacity G-force                  Designer  \
# 14        NaN                    NaN     NaN                       NaN
# 16       1:58                    NaN     NaN            John A. Miller
# 39       1:10     85 riders per hour    4 Gs           Harry G. Traver
# 43       1:10     85 riders per hour    4 Gs           Harry G. Traver
# 59       2:20                    NaN     NaN                 Ed Vettel
# ...       ...                    ...     ...                       ...
# 1063     0:40                    NaN     NaN                       NaN
# 1064      NaN                    NaN     NaN                       NaN
# 1080     1:50                    NaN     NaN              Alan Schilke
# 1082      NaN  1,500 riders per hour     4.7            Werner Stengel
# 1084    ~2:00  1,680 riders per hour       4  Walt Disney Imagineering
#
#      Max vertical angle           Drop Soft opening date Fast Lane available  \
# 14                  NaN            NaN               NaN                 NaN
# 16                  64°   70 ft (21 m)               NaN                 NaN
# 39                  59°   90 ft (27 m)               NaN                 NaN
# 43                  59°   90 ft (27 m)               NaN                 NaN
# 59                  NaN            NaN               NaN                 NaN
# ...                 ...            ...               ...                 ...
# 1063                NaN            NaN               NaN                 NaN
# 1064                NaN            NaN               NaN                 NaN
# 1080                91°  206 ft (63 m)               NaN                 NaN
# 1082                NaN            NaN               NaN                 NaN
# 1084                NaN            NaN               NaN                 NaN
#
#      Replaced           Track layout Fastrack available Soft opening date.1  \
# 14        NaN           Figure Eight                NaN                 NaN
# 16        NaN     Martin & Vleminckx                NaN                 NaN
# 39        NaN                Twister                NaN                 NaN
# 43        NaN                Twister                NaN                 NaN
# 59        NaN                    NaN                NaN                 NaN
# ...       ...                    ...                ...                 ...
# 1063      NaN  Single Helix (center)                NaN                 NaN
# 1064      NaN                   Oval                NaN                 NaN
# 1080    Gwazi                Twister                NaN                 NaN
# 1082      NaN                    NaN                NaN                 NaN
# 1084      NaN                    NaN                NaN                 NaN
#
#            Closing date Opened Replaced by Website Flash Pass Available  \
# 14                 1936    NaN         NaN     NaN                  NaN
# 16                 2005    NaN         NaN     NaN                  NaN
# 39    September 2, 1946    NaN         NaN     NaN                  NaN
# 43    September 2, 1946    NaN         NaN     NaN                  NaN
# 59                  NaN    NaN         NaN     NaN                  NaN
# ...                 ...    ...         ...     ...                  ...
# 1063                NaN    NaN         NaN     NaN                  NaN
# 1064                NaN    NaN         NaN     NaN                  NaN
# 1080                NaN    NaN         NaN     NaN                  NaN
# 1082                NaN    NaN         NaN     NaN                  NaN
# 1084                NaN    NaN         NaN     NaN                  NaN
#
#       Must transfer from wheelchair Theme  Single rider line available  \
# 14                              NaN   NaN                          NaN
# 16                              NaN   NaN                          NaN
# 39                              NaN   NaN                          NaN
# 43                              NaN   NaN                          NaN
# 59                              NaN   NaN                          NaN
# ...                             ...   ...                          ...
# 1063                            NaN   NaN                          NaN
# 1064                            NaN   NaN                          NaN
# 1080                            NaN   NaN                          NaN
# 1082                            NaN   NaN                          NaN
# 1084  Must transfer from wheelchair  Tron  Single rider line available
#
#      Restraint Style Flash Pass available Acceleration Restraints  \
# 14               NaN                  NaN          NaN        NaN
# 16               NaN                  NaN          NaN        NaN
# 39               NaN                  NaN          NaN        NaN
# 43               NaN                  NaN          NaN        NaN
# 59               NaN                  NaN          NaN        NaN
# ...              ...                  ...          ...        ...
# 1063             NaN                  NaN          NaN        NaN
# 1064             NaN                  NaN          NaN        NaN
# 1080             NaN                  NaN          NaN        NaN
# 1082             NaN                  NaN          NaN        NaN
# 1084             NaN                  NaN          NaN        NaN
#
#                        Name  year_introduced  latitude  longitude Type_Main  \
# 14                      NaN             1911   42.4200   -70.9860      Wood
# 16                      NaN             1912       NaN        NaN      Wood
# 39                      NaN             1926   42.8617   -79.0598      Wood
# 43                      NaN             1927   42.8617   -79.0598      Wood
# 59                      NaN             1937   41.6349   -80.3180      Wood
# ...                     ...              ...       ...        ...       ...
# 1063                    NaN             2021   40.1343   -74.4434     Steel
# 1064                    NaN             2021   41.6343   -80.3165     Steel
# 1080                    NaN             2022   28.0339   -82.4231     Steel
# 1082                    NaN             2022       NaN        NaN     Steel
# 1084  TRON Lightcycle / Run             2022       NaN        NaN     Steel
#
#      opening_date_clean     speed1     speed2  speed1_value speed1_unit  \
# 14           1911-01-01        NaN        NaN           NaN         NaN
# 16                  NaN    40 mph     64 km/h          40.0         mph
# 39           1926-01-01    60 mph     97 km/h          60.0         mph
# 43           1926-01-01    60 mph     97 km/h          60.0         mph
# 59           1938-05-23    50 mph     80 km/h          50.0         mph
# ...                 ...        ...        ...           ...         ...
# 1063         1999-01-01        NaN        NaN           NaN         NaN
# 1064         1950-01-01        NaN        NaN           NaN         NaN
# 1080                NaN    76 mph    122 km/h          76.0         mph
# 1082                NaN    53 mph     85 km/h          53.0         mph
# 1084         2016-06-16  59.3 mph   95.4 km/h          59.3         mph
#
#       speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 14          NaN           NaN         NaN        NaN                 0
# 16         40.0          70.0          ft        NaN                 0
# 39         60.0          96.0          ft        NaN                 0
# 43         60.0          96.0          ft        NaN                 0
# 59         50.0          77.0          ft        NaN                 0
# ...         ...           ...         ...        ...               ...
# 1063        NaN          13.0          ft        NaN                 0
# 1064        NaN           NaN         NaN        NaN                 0
# 1080       76.0         206.0          ft        NaN                 2
# 1082       53.0         111.0          ft        NaN                 3
# 1084       59.3          78.1          ft        NaN                 0
#
#       Gforce_clean
# 14             NaN
# 16             NaN
# 39             4.0
# 43             4.0
# 59             NaN
# ...            ...
# 1063           NaN
# 1064           NaN
# 1080           NaN
# 1082           4.7
# 1084           4.0
#
# [173 rows x 56 columns]

# %%
df.loc[df.duplicated(subset=['coaster_name'])].head(10)
# Out:
#                              coaster_name            Length             Speed  \
# 43                  Crystal Beach Cyclone  2,953 ft (900 m)  60 mph (97 km/h)
# 60                            Derby Racer               NaN               NaN
# 61            Blue Streak (Conneaut Lake)  2,900 ft (880 m)  50 mph (80 km/h)
# 167         Big Thunder Mountain Railroad               NaN  35 mph (56 km/h)
# 237     Thunder Run (Canada's Wonderland)  330 m (1,080 ft)  64 km/h (40 mph)
# 239                             La Vibora  1,490 ft (450 m)  32 mph (51 km/h)
# 241         Big Thunder Mountain Railroad               NaN  35 mph (56 km/h)
# 252                             La Vibora  1,490 ft (450 m)  32 mph (51 km/h)
# 262  Flashback (Six Flags Magic Mountain)  1,900 ft (580 m)  35 mph (56 km/h)
# 270                        Alpine Bobsled  1,490 ft (450 m)  35 mph (56 km/h)
#
#                 Location     Status  \
# 43    Crystal Beach Park    Removed
# 60          Revere Beach    Removed
# 61    Conneaut Lake Park     Closed
# 167                Other        NaN
# 237  Canada's Wonderland  Operating
# 239                Other        NaN
# 241                Other        NaN
# 252                Other        NaN
# 262                Other        NaN
# 270                Other        NaN
#
#                                           Opening date  \
# 43                                                1926
# 60                                                1911
# 61                                        May 23, 1938
# 167                                                NaN
# 237  May 23, 1981 as Blauer Enzian, 1986 as Thunder...
# 239                                                NaN
# 241                                                NaN
# 252                                                NaN
# 262                                                NaN
# 270                                                NaN
#
#                              Type  \
# 43                           Wood
# 60                  Wood – Racing
# 61                           Wood
# 167            Steel – Mine Train
# 237  Steel – Powered – Mine Train
# 239                         Steel
# 241            Steel – Mine Train
# 252                         Steel
# 262                         Steel
# 270                         Steel
#
#                                           Manufacturer  Height restriction  \
# 43                                  Traver Engineering                 NaN
# 60                                      Fred W. Pearce                 NaN
# 61                                                 NaN                 NaN
# 167  Arrow Development (California and Florida)Dyna...      40 in (102 cm)
# 237                                         Mack Rides  102 cm (3 ft 4 in)
# 239                                            Intamin      42 in (107 cm)
# 241  Arrow Development (California and Florida)Dyna...      40 in (102 cm)
# 252                                            Intamin      42 in (107 cm)
# 262                                            Intamin      48 in (122 cm)
# 270                                            Intamin      42 in (107 cm)
#
#                            Model         Height  Inversions  \
# 43                           NaN   96 ft (29 m)         NaN
# 60                           NaN            NaN         0.0
# 61   Out and Back roller coaster   77 ft (23 m)         0.0
# 167                   Mine Train  104 ft (32 m)         0.0
# 237                          NaN   10 m (33 ft)         0.0
# 239                    Swiss Bob   60 ft (18 m)         0.0
# 241                   Mine Train  104 ft (32 m)         0.0
# 252                    Swiss Bob   60 ft (18 m)         0.0
# 262                  Space Diver   86 ft (26 m)         0.0
# 270       Bobsled roller coaster   64 ft (20 m)         0.0
#
#     Lift/launch system           Cost  \
# 43          Chain-lift   $176,000 CDN
# 60                 NaN       $140,000
# 61                 NaN            NaN
# 167    Chain lift hill            NaN
# 237                NaN     $2.7M est.
# 239                NaN     $9 million
# 241    Chain lift hill            NaN
# 252                NaN     $9 million
# 262    Chain lift hill  $4,000,000[2]
# 270                NaN            NaN
#
#                                                 Trains  \
# 43                                                 NaN
# 60                                                 NaN
# 61   Single train with 3 cars. Riders are arranged ...
# 167                                                NaN
# 237  Single train with 10 cars. Riders are arranged...
# 239                                                NaN
# 241                                                NaN
# 252                                                NaN
# 262  3 trains with 5 cars. Riders are arranged 4 ac...
# 270  6 trains with a single car. Riders are arrange...
#
#                Park section        Duration                 Capacity G-force  \
# 43              Cyclone Bay            1:10       85 riders per hour    4 Gs
# 60                      NaN             NaN                      NaN     NaN
# 61                      NaN            2:20                      NaN     NaN
# 167                     NaN           ~3:00                      NaN     NaN
# 237  International Festival            1:24                      NaN     NaN
# 239        Mexico and Spain            1:30  600-675 riders per hour     NaN
# 241                     NaN           ~3:00                      NaN     NaN
# 252        Mexico and Spain            1:30  600-675 riders per hour     NaN
# 262         Six Flags Plaza            1:30    1,100 riders per hour       3
# 270               Fest Area  1 min. 40 sec.                      NaN     NaN
#
#                      Designer Max vertical angle          Drop  \
# 43            Harry G. Traver                59°  90 ft (27 m)
# 60                        NaN                NaN           NaN
# 61                  Ed Vettel                NaN           NaN
# 167  Walt Disney Imagineering                NaN           NaN
# 237                       NaN                NaN           NaN
# 239                       NaN                NaN           NaN
# 241  Walt Disney Imagineering                NaN           NaN
# 252                       NaN                NaN           NaN
# 262            Werner Stengel                89°  34 ft (10 m)
# 270                       NaN                NaN           NaN
#
#     Soft opening date Fast Lane available  \
# 43                NaN                 NaN
# 60                NaN                 NaN
# 61                NaN                 NaN
# 167               NaN                 NaN
# 237               NaN                 NaN
# 239               NaN                 NaN
# 241               NaN                 NaN
# 252               NaN                 NaN
# 262               NaN                 NaN
# 270               NaN                 NaN
#
#                                    Replaced  Track layout Fastrack available  \
# 43                                      NaN       Twister                NaN
# 60                                      NaN  Figure Eight                NaN
# 61                                      NaN           NaN                NaN
# 167  Mine Train Through Nature's Wonderland        Custom                NaN
# 237                                     NaN           NaN                NaN
# 239                                     NaN           NaN                NaN
# 241  Mine Train Through Nature's Wonderland        Custom                NaN
# 252                                     NaN           NaN                NaN
# 262                                     NaN           NaN                NaN
# 270                                     NaN           NaN                NaN
#
#     Soft opening date.1       Closing date Opened Replaced by Website  \
# 43                  NaN  September 2, 1946    NaN         NaN     NaN
# 60                  NaN               1936    NaN         NaN     NaN
# 61                  NaN                NaN    NaN         NaN     NaN
# 167                 NaN                NaN    NaN         NaN     NaN
# 237                 NaN                NaN    NaN         NaN     NaN
# 239                 NaN               1985    NaN   Shockwave     NaN
# 241                 NaN                NaN    NaN         NaN     NaN
# 252                 NaN               1985    NaN   Shockwave     NaN
# 262                 NaN                NaN    NaN         NaN     NaN
# 270                 NaN                NaN    NaN         NaN     NaN
#
#      Flash Pass Available  Must transfer from wheelchair Theme  \
# 43                    NaN                            NaN   NaN
# 60                    NaN                            NaN   NaN
# 61                    NaN                            NaN   NaN
# 167                   NaN  Must transfer from wheelchair   NaN
# 237                   NaN                            NaN   NaN
# 239  Flash Pass Available                            NaN   NaN
# 241                   NaN  Must transfer from wheelchair   NaN
# 252  Flash Pass Available                            NaN   NaN
# 262                   NaN                            NaN   NaN
# 270                   NaN                            NaN   NaN
#
#      Single rider line available Restraint Style Flash Pass available  \
# 43                           NaN             NaN                  NaN
# 60                           NaN             NaN                  NaN
# 61                           NaN             NaN                  NaN
# 167  Single rider line available             NaN                  NaN
# 237                          NaN             NaN                  NaN
# 239  Single rider line available             NaN                  NaN
# 241  Single rider line available             NaN                  NaN
# 252  Single rider line available             NaN                  NaN
# 262                          NaN             NaN                  NaN
# 270                          NaN             NaN                  NaN
#
#     Acceleration      Restraints Name  year_introduced  latitude  longitude  \
# 43           NaN             NaN  NaN             1927   42.8617   -79.0598
# 60           NaN             NaN  NaN             1937   42.4200   -70.9860
# 61           NaN             NaN  NaN             1938   41.6349   -80.3180
# 167          NaN  Single Lap Bar  NaN             1980       NaN        NaN
# 237          NaN             NaN  NaN             1986   43.8427   -79.5423
# 239          NaN             NaN  NaN             1986       NaN        NaN
# 241          NaN  Single Lap Bar  NaN             1987       NaN        NaN
# 252          NaN             NaN  NaN             1987       NaN        NaN
# 262          NaN             NaN  NaN             1988       NaN        NaN
# 270          NaN             NaN  NaN             1989       NaN        NaN
#
#     Type_Main opening_date_clean    speed1   speed2  speed1_value speed1_unit  \
# 43       Wood         1926-01-01   60 mph   97 km/h          60.0         mph
# 60       Wood         1911-01-01       NaN      NaN           NaN         NaN
# 61       Wood         1938-05-23   50 mph   80 km/h          50.0         mph
# 167     Steel                NaN   35 mph   56 km/h          35.0         mph
# 237     Steel         1981-05-23  64 km/h    40 mph          64.0        km/h
# 239     Steel                NaN   32 mph   51 km/h          32.0         mph
# 241     Steel                NaN   35 mph   56 km/h          35.0         mph
# 252     Steel                NaN   32 mph   51 km/h          32.0         mph
# 262     Steel                NaN   35 mph   56 km/h          35.0         mph
# 270     Steel                NaN   35 mph   56 km/h          35.0         mph
#
#      speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 43        60.0          96.0          ft        NaN                 0
# 60         NaN           NaN         NaN        NaN                 0
# 61        50.0          77.0          ft        NaN                 0
# 167       35.0         104.0          ft        NaN                 0
# 237       39.8          10.0           m       32.8                 0
# 239       32.0          60.0          ft        NaN                 0
# 241       35.0         104.0          ft        NaN                 0
# 252       32.0          60.0          ft        NaN                 0
# 262       35.0          86.0          ft        NaN                 0
# 270       35.0          64.0          ft        NaN                 0
#
#      Gforce_clean
# 43            4.0
# 60            NaN
# 61            NaN
# 167           NaN
# 237           NaN
# 239           NaN
# 241           NaN
# 252           NaN
# 262           3.0
# 270           NaN

# %%
df.query('coaster_name == "Crystal Beach Cyclone"')
# Out:
#              coaster_name            Length             Speed  \
# 39  Crystal Beach Cyclone  2,953 ft (900 m)  60 mph (97 km/h)
# 43  Crystal Beach Cyclone  2,953 ft (900 m)  60 mph (97 km/h)
#
#               Location   Status Opening date  Type        Manufacturer  \
# 39  Crystal Beach Park  Removed         1926  Wood  Traver Engineering
# 43  Crystal Beach Park  Removed         1926  Wood  Traver Engineering
#
#    Height restriction Model        Height  Inversions Lift/launch system  \
# 39                NaN   NaN  96 ft (29 m)         NaN         Chain-lift
# 43                NaN   NaN  96 ft (29 m)         NaN         Chain-lift
#
#             Cost Trains Park section Duration            Capacity G-force  \
# 39  $176,000 CDN    NaN  Cyclone Bay     1:10  85 riders per hour    4 Gs
# 43  $176,000 CDN    NaN  Cyclone Bay     1:10  85 riders per hour    4 Gs
#
#            Designer Max vertical angle          Drop Soft opening date  \
# 39  Harry G. Traver                59°  90 ft (27 m)               NaN
# 43  Harry G. Traver                59°  90 ft (27 m)               NaN
#
#    Fast Lane available Replaced Track layout Fastrack available  \
# 39                 NaN      NaN      Twister                NaN
# 43                 NaN      NaN      Twister                NaN
#
#    Soft opening date.1       Closing date Opened Replaced by Website  \
# 39                 NaN  September 2, 1946    NaN         NaN     NaN
# 43                 NaN  September 2, 1946    NaN         NaN     NaN
#
#    Flash Pass Available Must transfer from wheelchair Theme  \
# 39                  NaN                           NaN   NaN
# 43                  NaN                           NaN   NaN
#
#    Single rider line available Restraint Style Flash Pass available  \
# 39                         NaN             NaN                  NaN
# 43                         NaN             NaN                  NaN
#
#    Acceleration Restraints Name  year_introduced  latitude  longitude  \
# 39          NaN        NaN  NaN             1926   42.8617   -79.0598
# 43          NaN        NaN  NaN             1927   42.8617   -79.0598
#
#    Type_Main opening_date_clean   speed1   speed2  speed1_value speed1_unit  \
# 39      Wood         1926-01-01  60 mph   97 km/h          60.0         mph
# 43      Wood         1926-01-01  60 mph   97 km/h          60.0         mph
#
#     speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 39       60.0          96.0          ft        NaN                 0
# 43       60.0          96.0          ft        NaN                 0
#
#     Gforce_clean
# 39           4.0
# 43           4.0

# %% [markdown]
# ### <font color='blue'> <b>Check unique values</b><font color='black'>
# Hint: `df['column'].unique()`

# %%
df['coaster_name'].unique()
# Out:
# array(['Switchback Railway', 'Flip Flap Railway',
#        'Switchback Railway (Euclid Beach Park)',
#        'Loop the Loop (Coney Island)', "Loop the Loop (Young's Pier)",
#        'Cannon Coaster', 'Leap-The-Dips',
#        'Figure Eight (Euclid Beach Park)', 'Drop the Dip',
#        'Scenic Railway (Euclid Beach Park)',
#        'Loop the Loop (Olentangy Park)', 'Aero Dips',
#        'Backety-Back Scenic Railway', 'Racer (1910 roller coaster)',
#        'Derby Racer', 'The Great Scenic Railway', 'Zippin Pippin',
#        'Racing Coaster', 'Whirl Pool Dips',
#        'Green Dragon (Lake Compounce)', 'The Wild One (roller coaster)',
#        'Jack Rabbit (Clementon Park)', 'Jack Rabbit (Kennywood)',
#        'Jack Rabbit (Seabreeze)', 'Scenic Railway (roller coaster)',
#        'Roller Coaster (Lagoon)', 'Big Dipper (Blackpool Pleasure Beach)',
#        'Wild Cat (Hersheypark)', 'The Bobs (roller coaster)',
#        'Giant Dipper', 'Pippin (roller coaster)',
#        'The Thriller (roller coaster)', 'Thunderhawk (Dorney Park)',
#        'Big Dipper (Geauga Lake)', 'Cyclone (Revere Beach)',
#        'Giant Dipper (Belmont Park)', 'Jazz Railway',
#        'Thunderbolt (1925 roller coaster)', 'Thunderbolt (Savin Rock)',
#        'Crystal Beach Cyclone', 'Sesquicentennial Cyclone',
#        'Tornado (Coney Island)', 'Coney Island Cyclone',
#        'Cyclone (Palisades Amusement Park)', 'Lightning (Revere Beach)',
#        'Racer (Kennywood)', 'Wildcat (Lake Compounce)',
#        'Zip (roller coaster)', 'Airplane Coaster', 'Montaña Suiza',
#        'Dragon Coaster (Playland)', 'Flying Turns (Euclid Beach Park)',
#        'Yankee Cannonball',
#        'Roller Coaster (Great Yarmouth Pleasure Beach)',
#        'Nickelodeon Streak', 'Zipper Dipper',
#        'Big Dipper (Luna Park Sydney)', 'Grand National (roller coaster)',
#        'Blue Streak (Conneaut Lake)', 'Rollo Coaster',
#        'Cyclone (Lakeside Amusement Park)', 'Flyer Comet (Whalom Park)',
#        'Giant Skyrocket', 'Thunderbolt (Six Flags New England)',
#        'Comet (Hersheypark)', 'Comet (Lincoln Park)',
#        'Little Dipper (Conneaut Lake Park)',
#        'Little Dipper (Six Flags Great America)',
#        'Big Dipper (Battersea Park)', 'Comet (Waldameer)', 'Vuoristorata',
#        'Little Dipper (Memphis Kiddie Park)', 'High Speed Thrill Coaster',
#        'Sea Dragon (roller coaster)', 'Big Dipper (Camden Park)',
#        'Wild Mouse (Blackpool Pleasure Beach)',
#        'Wooden Roller Coaster (Playland)', 'Matterhorn Bobsleds',
#        'Tornado (Wedgewood Village Amusement Park)',
#        'Blue Streak (Cedar Point)', 'Jetstream (roller coaster)',
#        'Montaña Rusa (La Feria Chapultepec Mágico)',
#        'Giant Coaster (Fuji-Q Highland)',
#        'Runaway Mine Train (Six Flags Over Texas)',
#        'Swamp Fox (roller coaster)', 'Cannon Ball (roller coaster)',
#        'Dahlonega Mine Train', 'Alpine Sleigh Ride',
#        'Thunderbolt (Kennywood)', 'Cedar Creek Mine Ride',
#        'Mini Mine Train (Six Flags Over Texas)',
#        'Serpent (roller coaster)', 'Daidarasaurus', 'Galaxi',
#        'Jet Star (Casino Pier)', 'Wildcat (Jolly Roger Amusement Park)',
#        'Gold Rusher', 'Magic Flyer (roller coaster)',
#        'River King Mine Train', 'Excalibur (Six Flags AstroWorld)',
#        'Fire in the Hole (Silver Dollar City)', 'Jumbo Jet (Cedar Point)',
#        'The Racer (Kings Island)', "Rock n' Roller Coaster (Opryland)",
#        'Scooby-Doo (Kings Island)', 'Toboggan (Hersheypark)',
#        'Carolina Goldrusher',
#        'Great American Scream Machine (Six Flags Over Georgia)',
#        'Schussboomer', 'Big Fury', 'Mini-Comet',
#        'Runaway Mine Train (Six Flags Great Adventure)',
#        'Scooby-Doo (Kings Dominion)', 'Trailblazer (roller coaster)',
#        "Corkscrew (Knott's Berry Farm)", 'Glissade (roller coaster)',
#        'Racer 75', "Rockin' Roller", 'Scooby-Doo (Carowinds)',
#        'Space Mountain (Magic Kingdom)',
#        'Wabash Cannonball (roller coaster)', 'Alpen Blitz',
#        'Corkscrew (Cedar Point)', 'Demon (roller coaster)',
#        'Extremeroller', 'Gulf Coaster', 'High Roller (Valleyfair)',
#        'Jet Star 2 (Lagoon)', "Jumbo Jet (Morey's Piers)", "Lil' Thunder",
#        'Mild Thing', 'Python (Busch Gardens Tampa Bay)',
#        'The New Revolution (roller coaster)', "Screamin' Eagle",
#        'Texas Cyclone', 'Thunder Road (roller coaster)',
#        'Whizzer (roller coaster)', 'Double Loop (Geauga Lake)',
#        "Screamin' Demon", 'Shuttle Loop', 'SooperDooperLooper',
#        'Space Mountain (Disneyland)',
#        'Steeplechase (Blackpool Pleasure Beach)', 'Arkansas Twister',
#        'Colossus (Six Flags Magic Mountain)', 'Gemini (roller coaster)',
#        "Greezed Lightnin' (Six Flags Astroworld)", "Lightnin' Loops",
#        'Loch Ness Monster (roller coaster)', "Montezooma's Revenge",
#        'Schweizer Bobbahn', 'Shock Wave (Six Flags Over Texas)',
#        'The Riddler Mindbender', 'Tornado (Adventureland)', 'Wild Rider',
#        'The Beast (roller coaster)', 'Big Thunder Mountain Railroad',
#        'Big Thunder Mountain Railroad (Disneyland)',
#        "Corkscrew (Michigan's Adventure)",
#        'Momonga Standing and Loop Coaster',
#        'Revolution (Blackpool Pleasure Beach)',
#        'Rolling Thunder (roller coaster)', 'WildCat (Cedar Point)',
#        'Wilderness Run', 'Carolina Cyclone', 'Corkscrew (Alton Towers)',
#        'Corkscrew (Valleyfair)', 'Judge Roy Scream',
#        'Orient Express (roller coaster)', 'Scorpion (roller coaster)',
#        'Shuttle Loop (Nagashima Spa Land)', 'The Beastie (Kings Island)',
#        'American Eagle (roller coaster)',
#        'The Bat (Kings Island; opened 1981)',
#        'Colossus (Playcenter São Paulo)', 'Dragon Fyre',
#        "Ghoster Coaster (Canada's Wonderland)", 'Hoot N Holler',
#        'Mighty Canadian Minebuster', 'Python (Efteling)', 'Super Manège',
#        "Thunder Run (Canada's Wonderland)", 'Wilde Beast',
#        'Grizzly (Kings Dominion)', 'Looping Star (Nagashima Spa Land)',
#        'Sea Viper (roller coaster)', 'Thrillseeker (roller coaster)',
#        'Thunderbolt (Dreamworld)', 'Viper (Six Flags Darien Lake)',
#        'Vortex (Calaway Park)', 'Alpen Blitz (Parque de la Ciudad)',
#        'Beastie (Alton Towers)', 'Black Hole (roller coaster)',
#        'Colossus the Fire Dragon', 'Cyclone (Six Flags New England)',
#        'Dragon Mountain', 'Flitzer', 'Moonsault Scramble',
#        'Sky Screamer (Six Flags AstroWorld)',
#        'Space Mountain (Tokyo Disneyland)', 'Timberline Twister',
#        'Alpenexpress Enzian', 'Alpine Bobsled', 'Astro Storm',
#        'Big Bad Wolf (roller coaster)', 'Boomerang (roller coaster)',
#        'Flying Fish (roller coaster)', 'King Cobra (roller coaster)',
#        "Sea Serpent (Morey's Piers)", "Steamin' Demon", "Tig'rr Coaster",
#        'Ultra Twister (Nagashima Spa Land)', 'La Vibora', 'XLR-8',
#        'The Bush Beast', 'Disaster Transport',
#        'Flashback (Six Flags Magic Mountain)',
#        'Freestyle (roller coaster)', 'Kikkerachtbaan',
#        'Klondike Gold Mine (roller coaster)', 'Shaman (roller coaster)',
#        'Mindbender (Galaxyland)', 'Le Monstre',
#        'Phoenix (roller coaster)', 'Steel First', 'Swiss Bob',
#        'Texas Tornado (roller coaster)',
#        'The Beastie (Wonderland Sydney)', 'Wild Mouse (Idlewild)',
#        'Eureka Mountain Mine Ride', 'The Grizzly',
#        'Shockwave (Kings Dominion)', 'Silver Bullet (Frontier City)',
#        'Ultra Twister (Six Flags)', "The Bat (Canada's Wonderland)",
#        'Big Thunder Mountain Railroad (Tokyo Disneyland)',
#        'Canobie Corkscrew', 'Dreamcatcher (roller coaster)',
#        'Iron Dragon (roller coaster)', 'Knightmare (Camelot)',
#        'Lisebergbanan', 'Raptor Attack', 'Runaway Train (roller coaster)',
#        'Scorpion Express', 'Skyliner (roller coaster)',
#        'Vortex (Kings Island)',
#        "Woodstock's Express (California's Great America)",
#        'Avalanche (Blackpool Pleasure Beach)',
#        'Avalanche (Kings Dominion)', 'Bandit (Yomiuriland)',
#        'Beast (Alton Towers)', 'Boomerang (Six Flags México)',
#        'Cobra (La Ronde)', 'Crazy Bats', 'Jetline',
#        'Ninja (Six Flags Magic Mountain)', 'Raging Wolf Bobs',
#        'Shockwave (Six Flags Great America)', 'Thunderbolt Express',
#        'Wipeout (roller coaster)', 'Wolverine Wildcat',
#        'Anaconda (Walygator Parc)', 'Eurosat - CanCan Coaster',
#        'Excalibur (Valleyfair)', 'Flashback (Six Flags Over Texas)',
#        'Goudurix',
#        'Great American Scream Machine (Six Flags Great Adventure)',
#        'Hercules (roller coaster)', 'Magnum XL-200',
#        'Ninja (Six Flags St. Louis)', 'Olympia Looping',
#        'Timber Wolf (roller coaster)', 'Vekoma Illusion',
#        'Viper (Six Flags AstroWorld)', 'Corkscrew (Silverwood)',
#        'Dragon (Adventureland)', 'Flashback (Six Flags New England)',
#        'Iron Wolf (roller coaster)', 'Pikajuna',
#        'Predator (roller coaster)', 'Texas Giant', 'Thunder Looper',
#        'Thunder Run (Kentucky Kingdom)', 'Tigre de Sibérie',
#        'Twisted Cyclone', 'Vampire (roller coaster)',
#        'Viper (Six Flags Magic Mountain)', 'Adventure Express',
#        'Afterburner (Fun Spot)', 'Anaconda (roller coaster)',
#        'Pegasus (Efteling)', 'Psyclone (roller coaster)',
#        'Sidewinder (Hersheypark)', 'Steel Phantom',
#        'Toboggan (Lakemont Park)', 'Turbo Mountain',
#        'The Ultimate (roller coaster)', "Vortex (Canada's Wonderland)",
#        'Vortex (Great America)', 'Wildcat (Frontier City)',
#        'Batman: The Ride', 'Blue Hawk (roller coaster)',
#        'Cosmic Coaster (Valleyfair)', 'Desert Storm (roller coaster)',
#        'Drachen Fire', 'Dragon Coaster (Dorney Park)', 'Eagle Fortress',
#        'The Great Pumpkin Coaster', 'Jupiter (roller coaster)',
#        'Kingdom Coaster', 'Pepsi Orange Streak', 'Pipeline Express',
#        'The Rattler (roller coaster)',
#        'Runaway Mine Train (Alton Towers)', 'Sierra Tonante',
#        'Streamliner Coaster', 'Vortex (Carowinds)', 'Batman The Escape',
#        'Bocaraca', 'Canyon Blaster (Adventuredome)',
#        'Cosmic Coaster (Worlds of Fun)',
#        "Flight Deck (California's Great America)", "Gadget's Go Coaster",
#        'Hundeprutterutchebane', 'Indiana Jones et le Temple du Péril',
#        'Kumba (roller coaster)', 'Lightning Bolt (roller coaster)',
#        'Outlaw (roller coaster)',
#        'Superman: Krypton Coaster (Six Flags Mexico)', 'Thunderation',
#        'Top Gun (Kings Island)', 'The Comet (Great Escape)',
#        'Condor (roller coaster)', 'Corkscrew (Playland)',
#        'Desperado (roller coaster)', 'Diavlo', 'Hakugei (roller coaster)',
#        'Hoosier Hurricane', 'Hurler (roller coaster)',
#        'Nemesis (roller coaster)', 'Raptor (Cedar Point)',
#        'Roller Skater (roller coaster)', 'Shockwave (Drayton Manor)',
#        'The Big One (roller coaster)', 'Titan (Space World)',
#        'White Canyon (roller coaster)', "Zach's Zoomer",
#        'Arkham Asylum – Shock Therapy', 'Back at the Barnyard Hayride',
#        'The Gold Coaster', 'Cactus Coaster',
#        'Cannonball Express (roller coaster)',
#        'Cannonball Run (roller coaster)', 'Comet Express',
#        'Cyclops (roller coaster)', 'Dragon Khan',
#        'Eurostar (roller coaster)', "Flight Deck (Canada's Wonderland)",
#        "The Great Nor'easter", 'Jaguar!', 'The Raven (roller coaster)',
#        'Sidewinder (Elitch Gardens)',
#        'Space Mountain: De la Terre à la Lune',
#        'Space Shuttle (roller coaster)', 'T2 (roller coaster)',
#        'Twister II', 'Viper (Six Flags Great Adventure)',
#        'Viper (Six Flags Great America)',
#        'Viper (Six Flags Over Georgia)', 'Backyardigans: Mission to Mars',
#        'The Barnstormer', 'Colorado Adventure', 'Flight of Fear',
#        'Fujiyama (roller coaster)', "The Great White (Morey's Piers)",
#        'High Roller (Stratosphere)', 'Megafobia',
#        'Montu (roller coaster)',
#        'Pegasus (Mt. Olympus Water and Theme Park)',
#        'Rougarou (roller coaster)', 'Runaway Mountain',
#        'Santa Monica West Coaster', 'Skull Mountain',
#        "The Barnstormer at Goofy's Wiseacre Farm", "The Joker's Revenge",
#        'The Mind Eraser (Geauga Lake)', 'The Walking Dead: The Ride',
#        'Timber Terror', 'The Underground (roller coaster)',
#        'Wild Thing (Valleyfair)', 'Wildcat (Hersheypark)', 'Wilde maus',
#        'Alpengeist', 'Boomerang: Coast to Coaster',
#        'Chang (roller coaster)', 'Euro-Mir',
#        'The Great White (SeaWorld San Antonio)',
#        'Green Lantern (Six Flags Great Adventure)',
#        'Invertigo (roller coaster)', 'Kiddie Coaster',
#        'American Dreier Looping', 'Pyrenees (roller coaster)',
#        'Road Runner Express (Six Flags Fiesta Texas)',
#        'Big Apple Coaster', 'Skytrak', 'Stampida', 'Steel Force',
#        'Superman: Escape from Krypton', 'Tonnerre de Zeus',
#        'Tower of Terror II', 'Windjammer Surf Racers',
#        'Zeus (roller coaster)', 'Zoomerang (Lake Compounce)',
#        'Batman & Robin: The Chiller', 'Blue Tornado (roller coaster)',
#        'Doo Wopper', 'Excalibur (Funtown Splashtown USA)',
#        'GhostRider (roller coaster)', 'Great Bear (roller coaster)',
#        "Invertigo (California's Great America)", 'Journey to Atlantis',
#        'Kong (roller coaster)', 'Mad Cobra (roller coaster)',
#        'Mad Mouse (Pavilion)', 'Mamba (roller coaster)', 'Monte Makaya',
#        'Mr. Freeze (roller coaster)', 'Oblivion (roller coaster)',
#        'Rampage (roller coaster)', 'Rattlesnake (roller coaster)',
#        "The Riddler's Revenge", 'Roar (roller coaster)',
#        'Roller Coaster (Dam Sen Park)', "Scooby's Ghoster Coaster",
#        'Shivering Timbers', 'Sprocket Rockets',
#        'Storm Chaser (roller coaster)',
#        "Thunderhawk (Michigan's Adventure)",
#        'Vapor Trail (roller coaster)', 'Vogel Rok',
#        'Volcano: The Blast Coaster', 'Wild Mouse (Lagoon)',
#        'Wilderness Run (Carowinds)', 'Afterburn (roller coaster)',
#        "Apollo's Chariot", 'Bandit (Movie Park Germany)',
#        'Bizarro (roller coaster)',
#        'Canyon Blaster (Six Flags Magic Mountain)', 'Dragon Challenge',
#        'Exterminator (roller coaster)', 'Georgia Scorcher',
#        'Great Chase (Six Flags America)', 'Harley Quinn Crazy Train',
#        'The Howler', 'The Incredible Hulk Coaster',
#        'Invertigo (Kings Island)', 'Iron Gwazi', "The Joker's Jinx",
#        'Katapul', "Lil' Devil Coaster", 'Limit (roller coaster)',
#        "Mad Mouse (Michigan's Adventure)", 'Mad Mouse (Valleyfair)',
#        'Millennium Roller Coaster', 'Montaña Rusa (Parque del Café)',
#        'Montezum', 'Nightmare at Crack Axle Canyon',
#        'Poltergeist (roller coaster)',
#        'Powder Keg: A Blast into the Wilderness', 'Pteranodon Flyers',
#        'Python (Coney Island, Cincinnati, Ohio)',
#        'Raging Bull (roller coaster)',
#        'Road Runner Express (Six Flags Discovery Kingdom)',
#        "Rock 'n' Roller Coaster Starring Aerosmith", "Rollie's Coaster",
#        'Silver Comet (roller coaster)', 'Steel Eel',
#        'Superman – Ride of Steel', 'Tennessee Tornado',
#        'Thunderbolt (Celebration City)',
#        'Tornado (Parque de Atracciones de Madrid)',
#        'Tremors (roller coaster)', 'Twisted Typhoon',
#        'Twister (Knoebels Amusement Resort)', 'Two Face: The Flip Side',
#        'Wild Mouse (Hersheypark)', 'Woodstock Express (Cedar Point)',
#        "Woodstock Express (Michigan's Adventure)",
#        "Woody Woodpecker's Nuthouse Coaster",
#        'Batman: The Ride (Six Flags México)', 'Boomerang (Worlds of Fun)',
#        'The Boss (roller coaster)', 'Boulder Dash (roller coaster)',
#        "Catwoman's Whip", 'Dania Beach Hurricane', 'Diving Machine G5',
#        'Dominator (roller coaster)', 'Flying Dutchman Gold Mine',
#        'Flying Super Saturator', 'Flying Unicorn',
#        'Ghost Chasers (roller coaster)',
#        'Goliath (Six Flags Magic Mountain)',
#        'Gotham City Gauntlet: Escape from Arkham Asylum',
#        'Hurricane: Category 5', 'Jet Star (Luna Park)',
#        'Katun (roller coaster)', 'Kraken (roller coaster)',
#        'The Legend (roller coaster)', 'Lightning Racer', 'Linnunrata',
#        'Medusa (Six Flags Discovery Kingdom)', 'Mega Zeph',
#        'Millennium Force', 'Muskrat Scrambler',
#        'Possessed (roller coaster)', 'Ravine Flyer III', 'RC-48',
#        'Road Runner Express (Six Flags Kentucky Kingdom)',
#        'Road Runner Express (Six Flags New Orleans)',
#        'Road Runner Rollercoaster', 'Roller Coaster (Papéa Parc)',
#        'Roller Coaster (Suoi Tien Park)', 'Son of Beast',
#        'Speed – The Ride', 'Speed of Sound (roller coaster)',
#        'Steel Dragon 2000', 'Superman The Ride',
#        'Superman: Krypton Coaster', 'Svalbard Ekspressen',
#        'Untamed (Walibi Holland)', 'Villain (roller coaster)',
#        'Woodstock Express (Dorney Park)', 'Xpress: Platform 13',
#        'Zydeco Scream', 'Batwing (roller coaster)',
#        "California Screamin'", 'Cheetah (Wild Adventures)',
#        'Colossos - Kampf der Giganten', 'Cornball Express',
#        'Déjà Vu (roller coaster)', 'Do-Dodonpa', 'Expedition GeForce',
#        'Flying Ace Aerial Chase', 'Giant Inverted Boomerang',
#        "Goofy's Sky School", 'Hypersonic XLC', 'Incredicoaster',
#        'Insane Speed', 'Lego Technic Test Track', 'MP Xpress',
#        'Mulholland Madness', 'Nitro (Six Flags Great Adventure)',
#        "Phantom's Revenge", "Silver Streak (Canada's Wonderland)",
#        'Talon (roller coaster)', 'The Flash: Vertical Velocity',
#        'Thundercoaster (TusenFryd)', 'Titan (Six Flags Over Texas)',
#        'Vertical Velocity (roller coaster)', 'Vonkaputous',
#        'Wildfire (Silver Dollar City)',
#        "Wile E. Coyote's Grand Canyon Blaster", 'X-Flight (Geauga Lake)',
#        'Apple Zapple (Kings Dominion)', 'Avalancha (roller coaster)',
#        'Batman: The Dark Knight (roller coaster)',
#        'Batman: Arkham Asylum (roller coaster)', 'Colossus (Thorpe Park)',
#        'Escape from Madagascar', 'Flying Coaster (Elitch Gardens)',
#        'Galactica (roller coaster)', 'Goliath (Walibi Holland)',
#        'Jubilee Odyssey', 'Lost Coaster of Superstition Mountain',
#        'New Mexico Rattler', 'Primeval Whirl', 'Ricochet (Carowinds)',
#        'Roller Soaker', 'Rugrats Runaway Reptar (Dreamworld)',
#        'Scooby-Doo Spooky Coaster', 'Silver Star (roller coaster)',
#        'Star Jet', 'Superman: La Atracción de Acero',
#        'Superman: Ultimate Flight', 'Toboggan (Conneaut Lake Park)',
#        'Tom & Jerry (roller coaster)', 'Le Vampire', 'Wicked Twister',
#        "Winja's Fear & Force", 'X2 (roller coaster)', 'Xcelerator',
#        'Atlantis Adventure', 'Balder (roller coaster)',
#        'Canyon Blaster (Great Escape)', 'Dragon Express',
#        "Greased Lightnin' (Six Flags Discovery Kingdom)",
#        "Greezed Lightnin' (Kentucky Kingdom)",
#        'Half Pipe (roller coaster)', 'Jack Rabbit (Celebration City)',
#        'The Jester (roller coaster)', 'Kiddy Hawk', 'Nemesis Inferno',
#        'Ozark Wildcat', 'Scream (roller coaster)',
#        'Spider (roller coaster)', 'Steel Venom (Valleyfair)',
#        'Swamp Thing (Wild Adventures)', 'Thunder Dolphin',
#        'Top Thrill Dragster', "Twist n' Shout", 'Vild-Svinet',
#        'Vilda Musen', 'Booster Bike', 'Dæmonen',
#        "Dragon's Fury (roller coaster)", 'Fairly Odd Coaster', 'Hell Cat',
#        'The Joker Funhouse Coaster', 'Lightning (roller coaster)',
#        'Nighthawk (roller coaster)', "Ragin' Cajun (roller coaster)",
#        'Revenge of the Mummy', 'Sand Serpent',
#        'Shock Wave (Brean Leisure Park)',
#        "Silver Bullet (Knott's Berry Farm)", 'Spinball Whizzer',
#        'Spinning Dragons', 'Steel Dragon (Waldameer)', 'Storm Runner',
#        "Super Grover's Box Car Derby", 'Superman El Último Escape',
#        'The Gauntlet (roller coaster)', 'Thunderhead (roller coaster)',
#        'Time Warp (roller coaster)', 'Tulireki',
#        'Typhoon (Bobbejaanland)', 'WhirlWind (Seabreeze)',
#        'Atlantica SuperSplash', 'Bat (Lagoon)', 'Cobra (PowerPark)',
#        'Fairly Odd Coaster (Carowinds)', "Frankie's Mine Train",
#        'G Force (roller coaster)', 'Hades 360', 'Hydra the Revenge',
#        "Italian Job: Stunt Track (Canada's Wonderland)",
#        'Italian Job: Stunt Track (Kings Island)', 'Kanonen', 'Kingda Ka',
#        'Pandemonium (roller coaster)', 'Raging Spirits',
#        'Rita (roller coaster)', 'Sequoia Adventure', 'SheiKra',
#        'Space Mountain: Mission 2', 'Superman Escape',
#        'Wild Mouse (Beech Bend Park)', '10 Inversion Roller Coaster',
#        'Black Mamba (roller coaster)', 'Crystal Wing',
#        'Eejanaika (roller coaster)', 'Expedition Everest',
#        'Fairly Odd Coaster (Kings Island)', 'Golden Wings in Snowfield',
#        'Goliath (Six Flags Over Georgia)', 'Goliath (La Ronde)',
#        'Grand Exposition Coaster', 'Italian Job: Turbo Coaster',
#        'Jungle Racing', 'Kentucky Rumbler', 'Kumali',
#        'Patriot (Worlds of Fun)', 'Speed Monster', 'Speed: No Limits',
#        'Stealth (roller coaster)', 'Tatsu', 'Thunderbird (PowerPark)',
#        'El Toro (Six Flags Great Adventure)',
#        'The Voyage (roller coaster)', 'X-Coaster', 'Boardwalk Bullet',
#        "Crush's Coaster", 'De Vliegende Hollander',
#        'Firehawk (roller coaster)', 'Formule X', 'Furius Baco',
#        'Galaxy Orbiter', 'Griffon (roller coaster)',
#        'Hollywood Dream – The Ride', 'Infusion (roller coaster)',
#        "Jimmy Neutron's Atomic Flyer", 'Kirnu', 'Kvasten',
#        'Maverick (roller coaster)', "Mick Doohan's Motocoaster",
#        'Mystery Mine', 'Phaethon (roller coaster)',
#        'Rage (roller coaster)', 'Renegade (roller coaster)',
#        'Sierra Sidewinder', 'Star Flyer (roller coaster)', 'Surfrider',
#        'Troy (roller coaster)', 'Wicked (roller coaster)',
#        'American Thunder (roller coaster)', 'Backlot Stunt Coaster',
#        'Behemoth (roller coaster)', 'Cobra (Tivoli Friheden)',
#        'The Dark Knight Coaster', 'Dive Coaster (Chimelong Paradise)',
#        "Dragon's Run", 'Fahrenheit (roller coaster)',
#        'Flight Deck (Kings Island)', 'Flight of the Hippogriff',
#        'Goliath (Six Flags Fiesta Texas)', 'Jet Rescue', 'Kawasemi',
#        'Mammut (roller coaster)', 'Moto Coaster (Six Flags Darien Lake)',
#        'Muntanya Russa (Tibidabo Amusement Park)',
#        'Pony Express (roller coaster)', 'Ravine Flyer II',
#        'Roller Coaster (Dai Nam Van Hien)',
#        'Round About (roller coaster)', 'Salama (roller coaster)',
#        "Soak'd", 'SpongeBob SquarePants Rock Bottom Plunge', 'Steel Hawg',
#        'Steel Lasso', 'T Express', 'Tsunami (roller coaster)',
#        'Apocalypse: The Ride', 'Blue Fire', 'Diamondback (Kings Island)',
#        'Diving Coaster', 'Escape of Novgorod', 'Falcon (Duinrell)',
#        "Grover's Alpine Express", 'Hollywood Rip Ride Rockit',
#        'Hornet (roller coaster)', 'Insane (Gröna Lund)', 'ISpeed',
#        "Kozmo's Kurves", 'Manta (SeaWorld Orlando)',
#        'Mumbo Jumbo (roller coaster)', 'Prowler (roller coaster)',
#        'Saw – The Ride', 'Teststrecke', 'The Flying Cobras',
#        'El Toro (Freizeitpark Plohn)', 'Tranan',
#        'Wooden Coaster - Fireball', 'Air Grover',
#        'Battlestar Galactica (roller coaster)', 'Canopy Flyer',
#        "Ednör – L'Attaque", 'Enchanted Airways', 'Fiorano GT Challenge',
#        'Formula Rossa', 'Huracan (Belantis)',
#        'Intimidator (roller coaster)', 'Intimidator 305',
#        'Joris en de Draak', 'The Monster (Walygator Parc)', 'RC Racer',
#        'Sky Rocket', 'Space Fantasy – The Ride',
#        'Thirteen (roller coaster)', 'Viking Voyage',
#        'Woodstock Express (Carowinds)',
#        'Woodstock Express (Kings Island)', 'Accelerator (roller coaster)',
#        'Black Diamond (roller coaster)', 'Blue Flyer', 'BomBora (Lagoon)',
#        'BuzzSaw (roller coaster)', 'Cheetah Hunt', 'Dare Devil Dive',
#        'Eurofighter (Zoosafari Fasanolandia)', 'Green Lantern Coaster',
#        'Hair Raiser', 'Krake', 'New Texas Giant', 'Raptor (Gardaland)',
#        'Road Runner Express (Six Flags Magic Mountain)', 'Sky Scrapper',
#        "Soarin' Eagle", 'Takabisha', 'Tiger Express (roller coaster)',
#        'Timber Drop', 'Untamed (roller coaster)', "Van Helsing's Factory",
#        'Vipère (roller coaster)', 'Wood Coaster (Mountain Flyer)',
#        'Wooden Warrior', 'Big Grizzly Mountain Runaway Mine Cars',
#        'Cliffhanger (Colorado roller coaster)', 'Dauling Dragon',
#        'Dinoconda', 'Dragonfly (roller coaster)',
#        'Firebird (roller coaster)', 'Goliath (Six Flags New England)',
#        'Iron Shark', "Leviathan (Canada's Wonderland)",
#        'Manta (SeaWorld San Diego)', 'OzIris', 'Polar X-plorer',
#        'Shambhala (roller coaster)', 'Skyrush',
#        'Stinger (roller coaster)',
#        'Superman: Ultimate Flight (Six Flags Discovery Kingdom)',
#        'The Swarm (roller coaster)', 'Triops (roller coaster)',
#        'Verbolten', 'Wild Eagle', 'Wild West Express Coaster',
#        'Wodan Timbur Coaster', 'X-Flight (Six Flags Great America)',
#        'Abyss (roller coaster)', 'Boomerang (Six Flags St. Louis)',
#        'Coast Rider', 'Crazy Bird', 'Deep Space (roller coaster)',
#        'Flying Turns (Knoebels)', 'Freedom Flyer',
#        'Full Throttle (roller coaster)', 'GateKeeper (roller coaster)',
#        'Gold Striker', 'Iron Rattler', 'The Joker (Six Flags México)',
#        'Karacho', 'Nitro (Imagicaa)', 'Orkanen', 'Outlaw Run',
#        'Ring Racer', 'The Smiler', 'Smoky Mountain Alpine Coaster',
#        'Storm Coaster', 'White Lightning (roller coaster)', 'Wild Kitty',
#        'Woodstock Express (Kings Dominion)', 'Alpina Blitz',
#        'Arthur – The Ride', 'Banshee (roller coaster)',
#        'The Bat (Kings Island; opened 1993)',
#        'Dragon Wagon (Indiana Beach)',
#        'Family Inverted Coaster (Happy Valley Shanghai)',
#        'FireChaser Express', 'Flug der Dämonen',
#        'Goliath (Six Flags Great America)',
#        'Harry Potter and the Escape from Gringotts',
#        'Helix (roller coaster)', 'Lightning Run',
#        'El Loco (Adventuredome)', 'Medusa Steel Coaster',
#        'Parrot Coaster', 'Roar-o-Saurus', 'Seven Dwarfs Mine Train',
#        'Thunderbird (Holiday World)', 'Thunderbolt (2014 roller coaster)',
#        'Twist Coaster Robin', "Wonder Mountain's Guardian",
#        'Zimerman (roller coaster)', 'Acrobat (roller coaster)',
#        'Baron 1898', 'Batman: The Ride (S&S Free Spin)',
#        'Cannibal (roller coaster)', 'Fury 325',
#        'Harpy (Xishuangbanna Theme Park)', 'Impulse (roller coaster)',
#        'Jumbo Jet (Chelyuskintsev Park)', 'Junker (roller coaster)',
#        'Laff Trakk', 'Oblivion: The Black Hole',
#        'Octonauts Rollercoaster Adventure',
#        "Puss in Boots' Giant Journey", 'Rewind Racers',
#        'T3 (roller coaster)', 'Tempesto', 'The Cú Chulainn Coaster',
#        'The Oath of Kärnan', 'Turbulence (roller coaster)',
#        'Twisted Colossus', 'Wicked Cyclone', "ZDT's Amusement Park",
#        "Cobra's Curse", 'Flying Aces (roller coaster)',
#        'The Flying Dinosaur', 'Formuła (Energylandia)',
#        'The Joker (Six Flags Discovery Kingdom)',
#        'Lightning Rod (roller coaster)', 'Lost Gravity (roller coaster)',
#        'Mako (roller coaster)', 'The Monster (Adventureland)',
#        'Pulsar (roller coaster)', 'Raik', 'Recoil (Wonderla Hyderabad)',
#        'Taron (roller coaster)', 'The Joker (Six Flags Great Adventure)',
#        'Tron Lightcycle Power Run', 'Valravn (roller coaster)',
#        'Wildfire (Kolmården Wildlife Park)',
#        'Dawson Duel (roller coaster)', 'DC Rivals HyperCoaster',
#        'Gold Rush (Slagharen)', 'Hydrus (roller coaster)', 'InvadR',
#        'Lech Coaster', 'Mine Blower', 'Mystic Timbers',
#        "Patriot (California's Great America)", 'Pégase Express',
#        'Red Force (roller coaster)', 'Star Trek: Operation Enterprise',
#        'Star Wars Hyperspace Mountain',
#        'The Joker (Six Flags Great America)',
#        'The Joker (Six Flags New England)',
#        'The Joker (Six Flags Over Texas)',
#        'Wave Breaker: The Rescue Coaster', 'Adrenaline Peak',
#        'Electric Eel (roller coaster)', 'Fēnix (roller coaster)',
#        'HangTime (roller coaster)', 'Hyperion (roller coaster)',
#        'Icon (roller coaster)', "Merlin's Mayhem", 'RailBlazer',
#        'Slinky Dog Dash', 'Steel Vengeance', 'Tantrum (roller coaster)',
#        'Tiki-Waka (roller coaster)', 'Time Traveler (roller coaster)',
#        'Twisted Timbers', 'Valkyria (roller coaster)',
#        'Wicker Man (roller coaster)', 'Wonder Woman Coaster',
#        'Wonder Woman Golden Lasso Coaster', 'Copperhead Strike',
#        'Desmo Race', 'Dragonflier', 'Dynamite (Freizeitpark Plohn)',
#        'Fury (roller coaster)',
#        "Hagrid's Magical Creatures Motorbike Adventure",
#        'Hurricane (Fun Spot America)', 'Kentucky Flyer', 'Maxx Force',
#        'Mystic (roller coaster)', 'Nickelodeon Slime Streak',
#        'Panic Coaster – Back Daaan', 'Runaway Tram',
#        'Steel Curtain (roller coaster)', 'Taiga (roller coaster)',
#        'Tigris (roller coaster)', 'TMNT Shellraiser', 'Yukon Striker',
#        'Zadra (roller coaster)', 'Candymonium', 'F.L.Y. (roller coaster)',
#        'Max & Moritz (roller coaster)', 'Objectif Mars',
#        'Orion (roller coaster)', 'Pitts Special (roller coaster)',
#        "Sandy's Blasting Bronco", 'Texas Stingray',
#        'Wakala (roller coaster)', 'West Coast Racers', 'Abyssus',
#        'Dragon Slayer (roller coaster)', 'Jersey Devil Coaster', 'Kondaa',
#        'Krampus Expédition', 'Looping Star (Clacton Pier)',
#        'Monster (Gröna Lund)', 'Steel Taipan',
#        'Storm Chaser (Paultons Park)', 'Stunt Pilot (roller coaster)',
#        'The Ride to Happiness', 'VelociCoaster', 'Aquaman: Power Wave',
#        'ArieForce One', 'Defiance (roller coaster)',
#        'Dr. Diabolical’s Cliffhanger', 'Emperor (roller coaster)',
#        'Fønix (roller coaster)', 'Guardians of the Galaxy: Cosmic Rewind',
#        'Ice Breaker (roller coaster)', 'Leviathan (Sea World)',
#        'Pantheon (roller coaster)', 'Tumbili',
#        'Wonder Woman Flight of Courage'], dtype=object)

# %%
df.nunique()
# Out:
# coaster_name                     990
# Length                           569
# Speed                            243
# Location                         280
# Status                            15
# Opening date                     656
# Type                              98
# Manufacturer                     102
# Height restriction               100
# Model                            317
# Height                           382
# Inversions                        12
# Lift/launch system               116
# Cost                             272
# Trains                           221
# Park section                     271
# Duration                         208
# Capacity                         160
# G-force                           70
# Designer                         153
# Max vertical angle                83
# Drop                             235
# Soft opening date                 84
# Fast Lane available                1
# Replaced                         140
# Track layout                      95
# Fastrack available                 1
# Soft opening date.1               84
# Closing date                     144
# Opened                            16
# Replaced by                       67
# Website                           16
# Flash Pass Available               1
# Must transfer from wheelchair      1
# Theme                             33
# Single rider line available        1
# Restraint Style                    6
# Flash Pass available               1
# Acceleration                      50
# Restraints                        12
# Name                              18
# year_introduced                  101
# latitude                         688
# longitude                        691
# Type_Main                          3
# opening_date_clean               602
# speed1                           225
# speed2                           229
# speed1_value                     191
# speed1_unit                        2
# speed_mph                        176
# height_value                     322
# height_unit                        2
# height_ft                         92
# Inversions_clean                  12
# Gforce_clean                      45
# dtype: int64

# %% [markdown]
# ### <font color='blue'> <b>Calculate the basic statistical values</b><font color='black'>
# Hint:
#
# `df.describe().T`
#
# `df['column'].mean().round(2)`
#
# `df.agg({'column1':'max','column2':'mean', 'column3': 'std'})`

# %%
df.describe(include='all').T
# Out:
#                                 count unique  \
# coaster_name                     1087    990
# Length                            953    569
# Speed                             937    243
# Location                         1087    280
# Status                            874     15
# Opening date                      837    656
# Type                             1087     98
# Manufacturer                     1028    102
# Height restriction                831    100
# Model                             744    317
# Height                            965    382
# Inversions                      932.0    NaN
# Lift/launch system                795    116
# Cost                              382    272
# Trains                            718    221
# Park section                      487    271
# Duration                          765    208
# Capacity                          575    160
# G-force                           362     70
# Designer                          578    153
# Max vertical angle                357     83
# Drop                              494    235
# Soft opening date                  96     84
# Fast Lane available                69      1
# Replaced                          173    140
# Track layout                      335     95
# Fastrack available                 19      1
# Soft opening date.1                96     84
# Closing date                      236    144
# Opened                             27     16
# Replaced by                        88     67
# Website                            87     16
# Flash Pass Available               50      1
# Must transfer from wheelchair     106      1
# Theme                              44     33
# Single rider line available        81      1
# Restraint Style                    22      6
# Flash Pass available               46      1
# Acceleration                       60     50
# Restraints                         24     12
# Name                               35     18
# year_introduced                1087.0    NaN
# latitude                        812.0    NaN
# longitude                       812.0    NaN
# Type_Main                        1087      3
# opening_date_clean                837    602
# speed1                            937    225
# speed2                            935    229
# speed1_value                    937.0    NaN
# speed1_unit                       937      2
# speed_mph                       937.0    NaN
# height_value                    965.0    NaN
# height_unit                       965      2
# height_ft                       171.0    NaN
# Inversions_clean               1087.0    NaN
# Gforce_clean                    362.0    NaN
#
#                                                                              top  \
# coaster_name                                                    Batman: The Ride
# Length                                                            935 ft (285 m)
# Speed                                                           50 mph (80 km/h)
# Location                                                                   Other
# Status                                                                 Operating
# Opening date                                                                1972
# Type                                                                       Steel
# Manufacturer                                                              Vekoma
# Height restriction                                                48 in (122 cm)
# Model                                                                     Custom
# Height                                                              70 ft (21 m)
# Inversions                                                                   NaN
# Lift/launch system                                               Chain lift hill
# Cost                                                                  $2,000,000
# Trains                         2 trains with 6 cars. Riders are arranged 2 ac...
# Park section                                                       Planet Snoopy
# Duration                                                                    1:30
# Capacity                                                    1200 riders per hour
# G-force                                                                        4
# Designer                                                          Werner Stengel
# Max vertical angle                                                           90°
# Drop                                                               100 ft (30 m)
# Soft opening date                                                 April 29, 2005
# Fast Lane available                                          Fast Lane available
# Replaced                                  Mine Train Through Nature's Wonderland
# Track layout                                                             Twister
# Fastrack available                                            Fastrack available
# Soft opening date.1                                               April 29, 2005
# Closing date                                                  September 16, 2007
# Opened                                                                      1895
# Replaced by                                                            The Joker
# Website                                                         Official website
# Flash Pass Available                                        Flash Pass Available
# Must transfer from wheelchair                      Must transfer from wheelchair
# Theme                                                                  Toy Story
# Single rider line available                          Single rider line available
# Restraint Style                                                Over-the-shoulder
# Flash Pass available                                        Flash Pass available
# Acceleration                             0 to 40 mph (0 to 64 km/h) in 3 seconds
# Restraints                                                        Single Lap Bar
# Name                                                       Das große LEGO-Rennen
# year_introduced                                                              NaN
# latitude                                                                     NaN
# longitude                                                                    NaN
# Type_Main                                                                  Steel
# opening_date_clean                                                    1999-01-01
# speed1                                                                   50 mph
# speed2                                                                   80 km/h
# speed1_value                                                                 NaN
# speed1_unit                                                                  mph
# speed_mph                                                                    NaN
# height_value                                                                 NaN
# height_unit                                                                   ft
# height_ft                                                                    NaN
# Inversions_clean                                                             NaN
# Gforce_clean                                                                 NaN
#
#                               freq         mean         std       min  \
# coaster_name                     7          NaN         NaN       NaN
# Length                          21          NaN         NaN       NaN
# Speed                           63          NaN         NaN       NaN
# Location                       250          NaN         NaN       NaN
# Status                         668          NaN         NaN       NaN
# Opening date                     7          NaN         NaN       NaN
# Type                           308          NaN         NaN       NaN
# Manufacturer                   135          NaN         NaN       NaN
# Height restriction             224          NaN         NaN       NaN
# Model                           20          NaN         NaN       NaN
# Height                          20          NaN         NaN       NaN
# Inversions                     NaN      1.54721    2.114073       0.0
# Lift/launch system             411          NaN         NaN       NaN
# Cost                             6          NaN         NaN       NaN
# Trains                          52          NaN         NaN       NaN
# Park section                    14          NaN         NaN       NaN
# Duration                        59          NaN         NaN       NaN
# Capacity                        36          NaN         NaN       NaN
# G-force                         46          NaN         NaN       NaN
# Designer                       172          NaN         NaN       NaN
# Max vertical angle              45          NaN         NaN       NaN
# Drop                            15          NaN         NaN       NaN
# Soft opening date                4          NaN         NaN       NaN
# Fast Lane available             69          NaN         NaN       NaN
# Replaced                         6          NaN         NaN       NaN
# Track layout                    43          NaN         NaN       NaN
# Fastrack available              19          NaN         NaN       NaN
# Soft opening date.1              4          NaN         NaN       NaN
# Closing date                     8          NaN         NaN       NaN
# Opened                           7          NaN         NaN       NaN
# Replaced by                      4          NaN         NaN       NaN
# Website                         64          NaN         NaN       NaN
# Flash Pass Available            50          NaN         NaN       NaN
# Must transfer from wheelchair  106          NaN         NaN       NaN
# Theme                            4          NaN         NaN       NaN
# Single rider line available     81          NaN         NaN       NaN
# Restraint Style                 17          NaN         NaN       NaN
# Flash Pass available            46          NaN         NaN       NaN
# Acceleration                     4          NaN         NaN       NaN
# Restraints                       6          NaN         NaN       NaN
# Name                             4          NaN         NaN       NaN
# year_introduced                NaN  1994.986201   23.475248    1884.0
# latitude                       NaN    38.373484   15.516596  -48.2617
# longitude                      NaN   -41.595373   72.285227 -123.0357
# Type_Main                      816          NaN         NaN       NaN
# opening_date_clean              10          NaN         NaN       NaN
# speed1                          63          NaN         NaN       NaN
# speed2                          63          NaN         NaN       NaN
# speed1_value                   NaN    53.850374   23.385518       5.0
# speed1_unit                    780          NaN         NaN       NaN
# speed_mph                      NaN    48.617289   16.678031       5.0
# height_value                   NaN    89.575171  136.246444       4.0
# height_unit                    794          NaN         NaN       NaN
# height_ft                      NaN   101.996491   67.329092      13.1
# Inversions_clean               NaN     1.326587    2.030854       0.0
# Gforce_clean                   NaN     3.824006    0.989998       0.8
#
#                                     25%      50%      75%       max
# coaster_name                        NaN      NaN      NaN       NaN
# Length                              NaN      NaN      NaN       NaN
# Speed                               NaN      NaN      NaN       NaN
# Location                            NaN      NaN      NaN       NaN
# Status                              NaN      NaN      NaN       NaN
# Opening date                        NaN      NaN      NaN       NaN
# Type                                NaN      NaN      NaN       NaN
# Manufacturer                        NaN      NaN      NaN       NaN
# Height restriction                  NaN      NaN      NaN       NaN
# Model                               NaN      NaN      NaN       NaN
# Height                              NaN      NaN      NaN       NaN
# Inversions                          0.0      0.0      3.0      14.0
# Lift/launch system                  NaN      NaN      NaN       NaN
# Cost                                NaN      NaN      NaN       NaN
# Trains                              NaN      NaN      NaN       NaN
# Park section                        NaN      NaN      NaN       NaN
# Duration                            NaN      NaN      NaN       NaN
# Capacity                            NaN      NaN      NaN       NaN
# G-force                             NaN      NaN      NaN       NaN
# Designer                            NaN      NaN      NaN       NaN
# Max vertical angle                  NaN      NaN      NaN       NaN
# Drop                                NaN      NaN      NaN       NaN
# Soft opening date                   NaN      NaN      NaN       NaN
# Fast Lane available                 NaN      NaN      NaN       NaN
# Replaced                            NaN      NaN      NaN       NaN
# Track layout                        NaN      NaN      NaN       NaN
# Fastrack available                  NaN      NaN      NaN       NaN
# Soft opening date.1                 NaN      NaN      NaN       NaN
# Closing date                        NaN      NaN      NaN       NaN
# Opened                              NaN      NaN      NaN       NaN
# Replaced by                         NaN      NaN      NaN       NaN
# Website                             NaN      NaN      NaN       NaN
# Flash Pass Available                NaN      NaN      NaN       NaN
# Must transfer from wheelchair       NaN      NaN      NaN       NaN
# Theme                               NaN      NaN      NaN       NaN
# Single rider line available         NaN      NaN      NaN       NaN
# Restraint Style                     NaN      NaN      NaN       NaN
# Flash Pass available                NaN      NaN      NaN       NaN
# Acceleration                        NaN      NaN      NaN       NaN
# Restraints                          NaN      NaN      NaN       NaN
# Name                                NaN      NaN      NaN       NaN
# year_introduced                  1989.0   2000.0   2010.0    2022.0
# latitude                       35.03105  40.2898  44.7996   63.2309
# longitude                      -84.5522 -76.6536   2.7781  153.4265
# Type_Main                           NaN      NaN      NaN       NaN
# opening_date_clean                  NaN      NaN      NaN       NaN
# speed1                              NaN      NaN      NaN       NaN
# speed2                              NaN      NaN      NaN       NaN
# speed1_value                       40.0     50.0     63.0     240.0
# speed1_unit                         NaN      NaN      NaN       NaN
# speed_mph                          37.3     49.7     58.0     149.1
# height_value                       44.0     79.0    113.0    3937.0
# height_unit                         NaN      NaN      NaN       NaN
# height_ft                          51.8     91.2    131.2     377.3
# Inversions_clean                    0.0      0.0      2.0      14.0
# Gforce_clean                        3.4      4.0      4.5      12.0

# %%
df.describe().T
# Out:
#                    count         mean         std        min         25%  \
# Inversions         932.0     1.547210    2.114073     0.0000     0.00000
# year_introduced   1087.0  1994.986201   23.475248  1884.0000  1989.00000
# latitude           812.0    38.373484   15.516596   -48.2617    35.03105
# longitude          812.0   -41.595373   72.285227  -123.0357   -84.55220
# speed1_value       937.0    53.850374   23.385518     5.0000    40.00000
# speed_mph          937.0    48.617289   16.678031     5.0000    37.30000
# height_value       965.0    89.575171  136.246444     4.0000    44.00000
# height_ft          171.0   101.996491   67.329092    13.1000    51.80000
# Inversions_clean  1087.0     1.326587    2.030854     0.0000     0.00000
# Gforce_clean       362.0     3.824006    0.989998     0.8000     3.40000
#
#                         50%        75%        max
# Inversions           0.0000     3.0000    14.0000
# year_introduced   2000.0000  2010.0000  2022.0000
# latitude            40.2898    44.7996    63.2309
# longitude          -76.6536     2.7781   153.4265
# speed1_value        50.0000    63.0000   240.0000
# speed_mph           49.7000    58.0000   149.1000
# height_value        79.0000   113.0000  3937.0000
# height_ft           91.2000   131.2000   377.3000
# Inversions_clean     0.0000     2.0000    14.0000
# Gforce_clean         4.0000     4.5000    12.0000

# %% [markdown]
# ### <font color='blue'> <b>Outlier Analysis for 'colunm'</b><font color='black'>
#
# Hint:
# use the lib; `from scipy import stats`
#
# `z_scores = np.abs(stats.zscore(df['column']))`
#
# `outliers = np.where(z_scores >3)`
#
# `df.iloc[outliers]`

# %%
from scipy import stats

# %%
z_scores = np.abs(stats.zscore(df['height_value']))
z_scores
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1082   NaN
# 1083   NaN
# 1084   NaN
# 1085   NaN
# 1086   NaN
# Name: height_value, Length: 1087, dtype: float64

# %%
outliers = np.where(z_scores < 44.00000	)
outliers
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### <font color='blue'> <b>Calculate the ratio of age/sex... and necessery data</b><font color='black'>
# Hint:
# `df.Target.value_counts()`
#
# `df.Target.value_counts(normalize= True)`

# %%
df['Designer'].value_counts(normalize=True)
# Out:
# Designer
# Werner Stengel                                 0.297578
# Alan Schilke                                   0.067474
# Walt Disney Imagineering                       0.055363
# Ron Toomer                                     0.038062
# Vekoma                                         0.032872
#                                                  ...
# HUSS Park Attractions                          0.001730
# Curtis D. SummersJames FigleyLeonard Wright    0.001730
# Don Rosser and Bill Cobb                       0.001730
# Don Rosser & William Cobb                      0.001730
# Bolliger & Mabillard                           0.001730
# Name: proportion, Length: 153, dtype: float64

# %% [markdown]
# ### <font color='blue'> <b>Filter the 'column' has the values less than ..10...</b><font color='black'>
# Hint:
# `df['column'] <10`
#
# `df.query('column1 < 10 & column2 > 5') `

# %%
df.query('height_ft > 131 & speed1_value > 200')
# Out:
#       coaster_name              Length                 Speed  \
# 812  Formula Rossa  2,000 m (6,562 ft)  240 km/h (149.1 mph)
#
#                     Location     Status     Opening date              Type  \
# 812  Ferrari World Abu Dhabi  Operating  4 November 2010  Steel – Launched
#
#     Manufacturer                Height restriction                Model  \
# 812      Intamin  140–195 cm (4 ft 7 in–6 ft 5 in)  Accelerator Coaster
#
#               Height  Inversions      Lift/launch system Cost  \
# 812  52 m (170.6 ft)         0.0  Hydraulic Launch Track  NaN
#
#                                                 Trains Park section Duration  \
# 812  4 trains with 4 cars. Riders are arranged 2 ac...          NaN  1:32[1]
#
#                 Capacity G-force Designer Max vertical angle Drop  \
# 812  625 riders per hour  4.8[2]      NaN                NaN  NaN
#
#     Soft opening date Fast Lane available Replaced Track layout  \
# 812               NaN                 NaN      NaN          NaN
#
#     Fastrack available Soft opening date.1 Closing date Opened Replaced by  \
# 812                NaN                 NaN          NaN    NaN         NaN
#
#               Website Flash Pass Available Must transfer from wheelchair  \
# 812  Official website                  NaN                           NaN
#
#     Theme Single rider line available Restraint Style Flash Pass available  \
# 812   NaN                         NaN             NaN                  NaN
#
#                                     Acceleration Restraints Name  \
# 812  0 to 240 km/h (0 to 149 mph) in 4.9 seconds        NaN  NaN
#
#      year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 812             2010   24.4842    54.6124     Steel         2010-11-04
#
#         speed1     speed2  speed1_value speed1_unit  speed_mph  height_value  \
# 812  240 km/h   149.1 mph         240.0        km/h      149.1          52.0
#
#     height_unit  height_ft  Inversions_clean  Gforce_clean
# 812           m      170.6                 0           4.8

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# 1                         NaN                   Sea Lion Park
# 2                         NaN  Cleveland, Ohio, United States
# 3                         NaN                           Other
# 4                         NaN                           Other
# ...                       ...                             ...
# 1082         53 mph (85 km/h)                           Other
# 1083        73 mph (117 km/h)      Busch Gardens Williamsburg
# 1084  59.3[1] mph (95.4 km/h)                           Other
# 1085         34 mph (55 km/h)                  Kings Dominion
# 1086         58 mph (93 km/h)        Six Flags Magic Mountain
#
#                   Status   Opening date                                  Type  \
# 0                Removed  June 16, 1884                                  Wood
# 1                Removed           1895                                  Wood
# 2                 Closed            NaN                                 Other
# 3                Removed           1901                                 Steel
# 4                Removed           1901                                 Steel
# ...                  ...            ...                                   ...
# 1082                 NaN            NaN                                 Steel
# 1083  Under construction           2022                      Steel – Launched
# 1084                 NaN  June 16, 2016                      Steel – Launched
# 1085  Under construction            NaN  Steel – 4th Dimension – Wing Coaster
# 1086  Under construction           2022                   Steel – Single-rail
#
#                      Manufacturer Height restriction  \
# 0          LaMarcus Adna Thompson                NaN
# 1                    Lina Beecher                NaN
# 2                             NaN                NaN
# 3                  Edwin Prescott                NaN
# 4                  Edwin Prescott                NaN
# ...                           ...                ...
# 1082            Anton Schwarzkopf     55 in (140 cm)
# 1083                      Intamin                NaN
# 1084                       Vekoma   4[2] ft (122 cm)
# 1085    S&S – Sansei Technologies                NaN
# 1086  Rocky Mountain Construction                NaN
#
#                          Model            Height  Inversions  \
# 0                  Lift Packed      50 ft (15 m)         NaN
# 1                          NaN               NaN         1.0
# 2                          NaN               NaN         NaN
# 3                          NaN               NaN         1.0
# 4                          NaN               NaN         1.0
# ...                        ...               ...         ...
# 1082                       NaN     111 ft (34 m)         3.0
# 1083             Blitz Coaster     178 ft (54 m)         2.0
# 1084  Motorbike roller coaster  78.1 ft (23.8 m)         0.0
# 1085              4D Free Spin     112 ft (34 m)         0.0
# 1086           Raptor – Custom     131 ft (40 m)         3.0
#
#             Lift/launch system Cost  \
# 0                      gravity  NaN
# 1                          NaN  NaN
# 2                          NaN  NaN
# 3                          NaN  NaN
# 4                          NaN  NaN
# ...                        ...  ...
# 1082   Booster Wheel Lift Hill  NaN
# 1083                       LSM  NaN
# 1084                LIM Launch  NaN
# 1085  Vertical chain lift hill  NaN
# 1086           Chain lift hill  NaN
#
#                                                  Trains  \
# 0                                                   NaN
# 1     a single car. Riders are arranged 1 across in ...
# 2                                                   NaN
# 3     a single car. Riders are arranged 2 across in ...
# 4                                                   NaN
# ...                                                 ...
# 1082  3 trains with 5 cars. Riders are arranged 2 ac...
# 1083  2 trains with 5 cars. Riders are arranged 2 ac...
# 1084  7 trains with 7 cars. Riders are arranged 2 ac...
# 1085  Single car trains with riders arranged 4 acros...
# 1086                                                NaN
#
#                    Park section Duration               Capacity G-force  \
# 0     Coney Island Cyclone Site     1:00   1600 riders per hour     2.9
# 1                           NaN      NaN                    NaN      12
# 2                           NaN      NaN                    NaN     NaN
# 3                           NaN      NaN                    NaN     NaN
# 4                           NaN      NaN                    NaN     NaN
# ...                         ...      ...                    ...     ...
# 1082                        NaN      NaN  1,500 riders per hour     4.7
# 1083                        NaN      NaN                    NaN     NaN
# 1084                        NaN    ~2:00  1,680 riders per hour       4
# 1085          Jungle X-Pedition     0:55                    NaN     NaN
# 1086                DC Universe      NaN                    NaN     NaN
#
#                       Designer Max vertical angle           Drop  \
# 0       LaMarcus Adna Thompson                30°   43 ft (13 m)
# 1                 Lina Beecher                NaN            NaN
# 2                          NaN                NaN            NaN
# 3              Edward A. Green                NaN            NaN
# 4              Edward A. Green                NaN            NaN
# ...                        ...                ...            ...
# 1082            Werner Stengel                NaN            NaN
# 1083                       NaN                95°            NaN
# 1084  Walt Disney Imagineering                NaN            NaN
# 1085                       NaN                NaN            NaN
# 1086                       NaN                87°  127 ft (39 m)
#
#      Soft opening date Fast Lane available  \
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ...                ...                 ...
# 1082               NaN                 NaN
# 1083               NaN                 NaN
# 1084               NaN                 NaN
# 1085               NaN                 NaN
# 1086               NaN                 NaN
#
#                                     Replaced            Track layout  \
# 0                                        NaN  Gravity pulled coaster
# 1                                        NaN                     NaN
# 2                                        NaN                     NaN
# 3                         Switchback Railway                     NaN
# 4                                        NaN                     NaN
# ...                                      ...                     ...
# 1082                                     NaN                     NaN
# 1083                                     NaN                     NaN
# 1084                                     NaN                     NaN
# 1085                               The Crypt                     NaN
# 1086  Green Lantern: First Flight Tidal Wave                     NaN
#
#      Fastrack available Soft opening date.1 Closing date Opened  Replaced by  \
# 0                   NaN                 NaN          NaN    NaN          NaN
# 1                   NaN                 NaN         1902    NaN          NaN
# 2                   NaN                 NaN          NaN   1895          NaN
# 3                   NaN                 NaN         1910    NaN  Giant Racer
# 4                   NaN                 NaN         1912    NaN          NaN
# ...                 ...                 ...          ...    ...          ...
# 1082                NaN                 NaN          NaN    NaN          NaN
# 1083                NaN                 NaN          NaN    NaN          NaN
# 1084                NaN                 NaN          NaN    NaN          NaN
# 1085                NaN                 NaN          NaN    NaN          NaN
# 1086                NaN                 NaN          NaN    NaN          NaN
#
#                Website Flash Pass Available  Must transfer from wheelchair  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3                  NaN                  NaN                            NaN
# 4                  NaN                  NaN                            NaN
# ...                ...                  ...                            ...
# 1082               NaN                  NaN                            NaN
# 1083               NaN                  NaN                            NaN
# 1084               NaN                  NaN  Must transfer from wheelchair
# 1085  Official website                  NaN                            NaN
# 1086               NaN                  NaN                            NaN
#
#      Theme  Single rider line available Restraint Style Flash Pass available  \
# 0      NaN                          NaN             NaN                  NaN
# 1      NaN                          NaN             NaN                  NaN
# 2      NaN                          NaN             NaN                  NaN
# 3      NaN                          NaN             NaN                  NaN
# 4      NaN                          NaN             NaN                  NaN
# ...    ...                          ...             ...                  ...
# 1082   NaN                          NaN             NaN                  NaN
# 1083   NaN                          NaN             NaN                  NaN
# 1084  Tron  Single rider line available             NaN                  NaN
# 1085   NaN                          NaN             NaN                  NaN
# 1086   NaN                          NaN             NaN                  NaN
#
#      Acceleration Restraints                   Name  year_introduced  \
# 0             NaN        NaN                    NaN             1884
# 1             NaN        NaN                    NaN             1895
# 2             NaN        NaN                    NaN             1896
# 3             NaN        NaN                    NaN             1901
# 4             NaN        NaN                    NaN             1901
# ...           ...        ...                    ...              ...
# 1082          NaN        NaN                    NaN             2022
# 1083          NaN        NaN                    NaN             2022
# 1084          NaN        NaN  TRON Lightcycle / Run             2022
# 1085          NaN        NaN                    NaN             2022
# 1086          NaN        NaN                    NaN             2022
#
#       latitude  longitude Type_Main opening_date_clean     speed1     speed2  \
# 0      40.5740   -73.9780      Wood         1884-06-16     6 mph    9.7 km/h
# 1      40.5780   -73.9790      Wood         1895-01-01        NaN        NaN
# 2      41.5800   -81.5700     Other                NaN        NaN        NaN
# 3      40.5745   -73.9780     Steel         1901-01-01        NaN        NaN
# 4      39.3538   -74.4342     Steel         1901-01-01        NaN        NaN
# ...        ...        ...       ...                ...        ...        ...
# 1082       NaN        NaN     Steel                NaN    53 mph     85 km/h
# 1083   37.2339   -76.6426     Steel         2022-01-01    73 mph    117 km/h
# 1084       NaN        NaN     Steel         2016-06-16  59.3 mph   95.4 km/h
# 1085       NaN        NaN     Steel                NaN    34 mph     55 km/h
# 1086       NaN        NaN     Steel         2022-01-01    58 mph     93 km/h
#
#       speed1_value speed1_unit  speed_mph  height_value height_unit  \
# 0              6.0         mph        6.0          50.0          ft
# 1              NaN         NaN        NaN           NaN         NaN
# 2              NaN         NaN        NaN           NaN         NaN
# 3              NaN         NaN        NaN           NaN         NaN
# 4              NaN         NaN        NaN           NaN         NaN
# ...            ...         ...        ...           ...         ...
# 1082          53.0         mph       53.0         111.0          ft
# 1083          73.0         mph       73.0         178.0          ft
# 1084          59.3         mph       59.3          78.1          ft
# 1085          34.0         mph       34.0         112.0          ft
# 1086          58.0         mph       58.0         131.0          ft
#
#       height_ft  Inversions_clean  Gforce_clean
# 0           NaN                 0           2.9
# 1           NaN                 1          12.0
# 2           NaN                 0           NaN
# 3           NaN                 1           NaN
# 4           NaN                 1           NaN
# ...         ...               ...           ...
# 1082        NaN                 3           4.7
# 1083        NaN                 2           NaN
# 1084        NaN                 0           4.0
# 1085        NaN                 0           NaN
# 1086        NaN                 3           NaN
#
# [1087 rows x 56 columns]

# %% [markdown]
# ### <font color='blue'> <b>Calculate the correlation of 'column' with other features (Correlation Analysis)</b><font color='black'>
#
# Hint:
# - `df.corr()['column'].sort_values(ascending= False)`
# - `df[['column1', 'column2', 'column3'...]].dropna().corr()`

# %%
df[['year_introduced', 'speed_mph', 'height_ft']].dropna().corr()
# Out:
#                  year_introduced  speed_mph  height_ft
# year_introduced         1.000000   0.246314   0.252420
# speed_mph               0.246314   1.000000   0.829404
# height_ft               0.252420   0.829404   1.000000

# %% [markdown]
# ## <font color='Navy'> <b>Step 2: Data Preperation</b><font color='black'>
# - Dropping irrelevant columns and rows
# - Identifying duplicated columns
# - Renaming Columns
# - Feature Creation

# %% [markdown]
# ### <font color='blue'> <b>Change the column names if necessary</b><font color='black'>
# Hint:
#
# - `df.rename(columns=lambda x: x.split('(')[0], inplace=True)`  or
# - `df.rename(columns=str.lower, inplace=True)`
# - `df.columns.str.lower()`
# - `df.columns = ['X',	'Y',	'Z'.....]`

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['coaster_name', 'length', 'speed', 'location', 'status', 'opening date',
#        'type', 'manufacturer', 'height restriction', 'model', 'height',
#        'inversions', 'lift/launch system', 'cost', 'trains', 'park section',
#        'duration', 'capacity', 'g-force', 'designer', 'max vertical angle',
#        'drop', 'soft opening date', 'fast lane available', 'replaced',
#        'track layout', 'fastrack available', 'soft opening date.1',
#        'closing date', 'opened', 'replaced by', 'website',
#        'flash pass available', 'must transfer from wheelchair', 'theme',
#        'single rider line available', 'restraint style',
#        'flash pass available', 'acceleration', 'restraints', 'name',
#        'year_introduced', 'latitude', 'longitude', 'type_main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'inversions_clean', 'gforce_clean'],
#       dtype='object')

# %% [markdown]
# ### <font color='blue'> <b> Create a new column giving the ....</b><font color='black'>
# Hint: `df['column1']= df['column2'] - df['column3']`

# %% [markdown]
# ### <font color='blue'> <b>Convert the Time to.... if necessery (Time Series Transformation)</b><font color='black'>
#
# Hint:
# `df['Years'] = df['Time'] // 12`
#
# `df['Month'] = df['Time'] % 12`
# `

# %%
# yeni df olusturuldu, bazi columnlar secildi kullanildi

# %%
df1 = df[['coaster_name',
    # 'Length', 'Speed',
    'location', 'status',
    # 'Opening date',
    #   'Type',
    'manufacturer',
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date',
#     'Opened', 
    # 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
        'latitude', 'longitude',
    'type_main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit',
    'height_ft',
       'inversions_clean', 'gforce_clean']].copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   location            1087 non-null   object
#  2   status              874 non-null    object
#  3   manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   type_main           1087 non-null   object
#  8   opening_date_clean  837 non-null    object
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  inversions_clean    1087 non-null   int64
#  12  gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 110.5+ KB

# %%
df1['opening_date_clean'] = pd.to_datetime(df1['opening_date_clean'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   location            1087 non-null   object
#  2   status              874 non-null    object
#  3   manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   type_main           1087 non-null   object
#  8   opening_date_clean  837 non-null    datetime64[ns]
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  inversions_clean    1087 non-null   int64
#  12  gforce_clean        362 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 110.5+ KB

# %% [markdown]
# ### <font color='blue'> <b>Create a new column by groups based on 'columnX' (Grouping and Aggregation)</b><font color='black'>
#
# Hint:
# `bins = [0,5,10,50]`
#
# `group_names =['Low','Medium','High']`
#
# `df['Frequency_Group'] = pd.cut(df['column'], bins, labels = group_names)`

# %% [markdown]
# ### <font color='blue'> <b> Fill the missing values</b><font color='black'>
# Hint:
# Numerical values;
# - `df['column1'].fillna(df['column1'].mean())`
#
# Categorical values;
# - `df['dept'].fillna(df['dept'].mode()[0])`
# - `df['dept'].fillna(method='ffill', inplace=True)`  or `bfill`
#
# Filling by condition & group;
# - `df.loc[df['salary'] >= 100, 'status'] =  df.loc[df['salary'] >= 100, 'status'].fillna(df.loc[df['salary'] >= 100, 'status'].mode()[0])`
# - `df['status'].fillna(df.groupby(['dept'])['status'].transform(lambda x: x.mode()[0]), inplace=True)`
# - `df['salary'].fillna(df.groupby(['status','dept'])['salary'].transform('mean'),inplace=True)`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   length                         953 non-null    object
#  2   speed                          937 non-null    object
#  3   location                       1087 non-null   object
#  4   status                         874 non-null    object
#  5   opening date                   837 non-null    object
#  6   type                           1087 non-null   object
#  7   manufacturer                   1028 non-null   object
#  8   height restriction             831 non-null    object
#  9   model                          744 non-null    object
#  10  height                         965 non-null    object
#  11  inversions                     932 non-null    float64
#  12  lift/launch system             795 non-null    object
#  13  cost                           382 non-null    object
#  14  trains                         718 non-null    object
#  15  park section                   487 non-null    object
#  16  duration                       765 non-null    object
#  17  capacity                       575 non-null    object
#  18  g-force                        362 non-null    object
#  19  designer                       578 non-null    object
#  20  max vertical angle             357 non-null    object
#  21  drop                           494 non-null    object
#  22  soft opening date              96 non-null     object
#  23  fast lane available            69 non-null     object
#  24  replaced                       173 non-null    object
#  25  track layout                   335 non-null    object
#  26  fastrack available             19 non-null     object
#  27  soft opening date.1            96 non-null     object
#  28  closing date                   236 non-null    object
#  29  opened                         27 non-null     object
#  30  replaced by                    88 non-null     object
#  31  website                        87 non-null     object
#  32  flash pass available           50 non-null     object
#  33  must transfer from wheelchair  106 non-null    object
#  34  theme                          44 non-null     object
#  35  single rider line available    81 non-null     object
#  36  restraint style                22 non-null     object
#  37  flash pass available           46 non-null     object
#  38  acceleration                   60 non-null     object
#  39  restraints                     24 non-null     object
#  40  name                           35 non-null     object
#  41  year_introduced                1087 non-null   int64
#  42  latitude                       812 non-null    float64
#  43  longitude                      812 non-null    float64
#  44  type_main                      1087 non-null   object
#  45  opening_date_clean             837 non-null    object
#  46  speed1                         937 non-null    object
#  47  speed2                         935 non-null    object
#  48  speed1_value                   937 non-null    float64
#  49  speed1_unit                    937 non-null    object
#  50  speed_mph                      937 non-null    float64
#  51  height_value                   965 non-null    float64
#  52  height_unit                    965 non-null    object
#  53  height_ft                      171 non-null    float64
#  54  inversions_clean               1087 non-null   int64
#  55  gforce_clean                   362 non-null    float64
# dtypes: float64(8), int64(2), object(46)
# memory usage: 475.7+ KB

# %%
df['inversions'] = df['inversions'].fillna(df['inversions'].mean())

# %%
df['length'] = df['length'].fillna(df['length'].mode())
df['length']
# Out:
# 0             600 ft (180 m)
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#                 ...
# 1082      3,444 ft (1,050 m)
# 1083      3,328 ft (1,014 m)
# 1084    3,169.3 ft (966.0 m)
# 1085          770 ft (230 m)
# 1086      3,300 ft (1,000 m)
# Name: length, Length: 1087, dtype: object

# %%
df.isnull().sum()
# Out:
# coaster_name                        0
# length                            134
# speed                             150
# location                            0
# status                            213
# opening date                      250
# type                                0
# manufacturer                       59
# height restriction                256
# model                             343
# height                            122
# inversions                          0
# lift/launch system                292
# cost                              705
# trains                            369
# park section                      600
# duration                          322
# capacity                          512
# g-force                           725
# designer                          509
# max vertical angle                730
# drop                              593
# soft opening date                 991
# fast lane available              1018
# replaced                          914
# track layout                      752
# fastrack available               1068
# soft opening date.1               991
# closing date                      851
# opened                           1060
# replaced by                       999
# website                          1000
# flash pass available             1037
# must transfer from wheelchair     981
# theme                            1043
# single rider line available      1006
# restraint style                  1065
# flash pass available             1041
# acceleration                     1027
# restraints                       1063
# name                             1052
# year_introduced                     0
# latitude                          275
# longitude                         275
# type_main                           0
# opening_date_clean                250
# speed1                            150
# speed2                            152
# speed1_value                      150
# speed1_unit                       150
# speed_mph                         150
# height_value                      122
# height_unit                       122
# height_ft                         916
# inversions_clean                    0
# gforce_clean                      725
# dtype: int64

# %% [markdown]
# ## <font color='Navy'> <b>Step 3: Feature Understanding</b><font color='black'>
# - (Univariate analysis)
#
#     - Plotting Feature Distributions
#     - Histogram
#     - KDE
#     - Boxplot

# %%
df['year_introduced'].value_counts()
# Out:
# year_introduced
# 1999    49
# 2000    47
# 1998    32
# 2011    31
# 2001    30
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
ax = df['year_introduced'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Years Coasters Introduced')

ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['speed_mph'].plot(kind='hist',
                          bins=20,
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
ax = df['speed_mph'].plot(kind='kde',
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %% [markdown]
# ## <font color='Navy'> <b>Step 4: Feature Relationships</b><font color='black'>
# - Scatterplot
# - Heatmap Correlation
# - Pairplot
# - Groupby comparisons

# %%
df.plot(kind='scatter',
        x='speed_mph',
        y='height_ft',
        title='Coaster Speed vs. Height')
plt.show()

# %%
ax = sns.scatterplot(x='speed_mph',
                y='height_ft',
                hue='year_introduced',
                data=df)
ax.set_title('Coaster Speed vs. Height')
plt.show()

# %%
df['type_main'] = df['type_main'].astype('category')

# %%
sns.pairplot(df,
            vars=['year_introduced','speed_mph','height_ft','inversions'],
            hue='lenght')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3920\1103587733.py in ?()
# ----> 1 sns.pairplot(df,
#       2             vars=['year_introduced','speed_mph','height_ft','inversions'],
#       3             hue='inversions')
#       4 plt.show()
#
# ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py in ?(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2110             diag_kind = "hist" if kind == "hist" else "kde"
#    2111
#    2112     # Set up the PairGrid
#    2113     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2114     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2115                     hue_order=hue_order, palette=palette, corner=corner,
#    2116                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2117
#
# ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py in ?(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1241
#    1242         super().__init__()
#    1243
#    1244         # Sort out the variables that define the grid
# -> 1245         numeric_cols = self._find_numeric_cols(data)
#    1246         if hue in numeric_cols:
#    1247             numeric_cols.remove(hue)
#    1248         if vars is not None:
#
# ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py in ?(self, data)
#    1664     def _find_numeric_cols(self, data):
#    1665         """Find which variables in a DataFrame are numeric."""
#    1666         numeric_cols = []
#    1667         for col in data:
# -> 1668             if variable_type(data[col]) == "numeric":
#    1669                 numeric_cols.append(col)
#    1670         return numeric_cols
#
# ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py in ?(vector, boolean_type)
#    1498     if pd.api.types.is_categorical_dtype(vector):
#    1499         return VariableType("categorical")
#    1500
#    1501     # Special-case all-na data, which is always "numeric"
# -> 1502     if pd.isna(vector).all():
#    1503         return VariableType("numeric")
#    1504
#    1505     # Special-case binary/boolean data, allow caller to determine
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_corr = df[['year_introduced','speed_mph','height_ft','inversions']].dropna().corr()
df_corr
# Out:
#                  year_introduced  speed_mph  height_ft  inversions
# year_introduced         1.000000   0.246314   0.252420    0.096026
# speed_mph               0.246314   1.000000   0.829404    0.178669
# height_ft               0.252420   0.829404   1.000000    0.133610
# inversions              0.096026   0.178669   0.133610    1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## <font color='Navy'> <b>Step 5: Ask a Question about the data</b><font color='black'>
# - Try to answer a question you have about the data using a plot or statistic.
#     - Exp: What are the locations with the fastest roller coasters (minimum of 10)?

# %%
ax = df[df['location'] != "Other"] \
    .groupby('location')['speed_mph'] \
    .agg(['mean', 'count']) \
    .query('count >= 10') \
    .sort_values('mean') \
    .plot(kind='barh', y='mean', figsize=(12, 5), title='Average Coast Speed by Location')

ax.set_xlabel('Average Coaster Speed (mph)')
ax.set_ylabel('Location')

plt.show()

# %% [markdown]
# # <p style="background-color:dodgerblue;font-family:arial;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Thank you for your contributions
# </b></p>
#
# <b>please do not forget to follow us </b>[Linkedin](https://www.linkedin.com/in/duygujones/) | [Kaggle](https://www.kaggle.com/duygujones) | [Tableau](https://public.tableau.com/app/profile/duygu.jones/vizzes) | [Source]()
